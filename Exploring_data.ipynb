# %% [markdown]
# <h1>Data Munging of OpenStreetMaps data</h1>

# %% [markdown]
# Home to the world famous biryani and the topic for my data wrangling with MongoDB - Hyderabad!
#
# After downloading my dataset from MapZen URL.The whole file is around 731MB which is too large for my computer to process. Hence, I have sampled the dataset to 83MB to carry out the data munging process.

# %%
OSM_FILE = 'HYD_OSM.osm'

# %% [markdown]
# To audit the osm file, first we need to know the overview of the data. To get an overview of the data, we count the tag content of the data. I ran it against the mapparser.py to get to the unique number of tags.

# %%
# %load mapparser.py
#!/usr/bin/env python

import xml.etree.ElementTree as ET
import pprint

def count_tags(filename):
    """count tags in filename."""
    tags = {}
    for ev,elem in ET.iterparse(filename):
        tag = elem.tag
        if tag not in tags.keys():
            tags[tag] = 1
        else:
            tags[tag]+=1
    return tags

pprint.pprint(count_tags(OSM_FILE))
# Out:
# {'member': 1367,
#  'nd': 407095,
#  'node': 322802,
#  'osm': 1,
#  'relation': 227,
#  'tag': 86311,
#  'way': 77012}

# %% [markdown]
# Exploring tag values in the file

# %%
# %load tags.py
#!/usr/bin/env python
import xml.etree.ElementTree as ET
import pprint
import re


lower = re.compile(r'^([a-z]|_)*$')
lower_colon = re.compile(r'^([a-z]|_)*:([a-z]|_)*$')
problemchars = re.compile(r'[=\+/&<>;\'"\?%#$@\,\. \t\r\n]')


def key_type(element, keys):
    """ 
    Count the criteria in dictionary for the content of the tag.
    """
    if element.tag == "tag":
        if lower.search(element.attrib['k']):
            keys['lower'] +=1
        elif lower_colon.search(element.attrib['k']):
            keys['lower_colon']+=1
        elif problemchars.search(element.attrib['k']):
            keys['problemchars']+=1
        else:
            keys['other']+=1
        
    return keys



def process_map(filename):
    keys = {"lower": 0, "lower_colon": 0, "problemchars": 0, "other": 0}
    for _, element in ET.iterparse(filename):
        keys = key_type(element, keys)

    return keys



def test():
    # You can use another testfile 'map.osm' to look at your solution
    # Note that the assertions will be incorrect then.
    keys = process_map(OSM_FILE)
    pprint.pprint(keys)
#     assert keys == {'lower': 5, 'lower_colon': 0, 'other': 2, 'problemchars': 0}


if __name__ == "__main__":
    test()
# Out:
# {'lower': 85790, 'lower_colon': 488, 'other': 29, 'problemchars': 4}

# %% [markdown]
# The "k" value of each tag contain different patterns. Using tags.py which has 3 regular expressions to check for certain patterns in the tags.
# The three patterns will check for Lower-case patterns and which are valid. We have 85790 of them.
# The second pattern checks for lower case with colon values, we have 488 of them.
# We have 4 values which have problem characters which can include '?/!/#' etc.
# We have 29 other tags that don't fall into any of these categories.

# %%
85790# %load users.py

#!/usr/bin/env python
# -*- coding: utf-8 -*-
import xml.etree.ElementTree as ET
import pprint
import re

def get_user(element):
    return


def process_map(filename):
    """
    Count the user id in the filename.
    """
    users = set()
    for _, element in ET.iterparse(filename):
        try:
            users.add(element.attrib['uid'])
        except KeyError:
            continue

    return users


def test():

    users = process_map(OSM_FILE)
    pprint.pprint(users)
#     assert len(users) == 6



if __name__ == "__main__":
    test()
# Out:
# set(['100487',
#      '1008085',
#      '101441',
#      '1016290',
#      '1031039',
#      '103253',
#      '1051550',
#      '1069176',
#      '109217',
#      '110263',
#      '110639',
#      '1112761',
#      '111849',
#      '1127874',
#      '112975',
#      '116609',
#      '118021',
#      '1229564',
#      '1240849',
#      '1281349',
#      '1295796',
#      '1300764',
#      '130472',
#      '1306',
#      '132740',
#      '13303',
#      '13363',
#      '135290',
#      '136860',
#      '1386982',
#      '1408522',
#      '1420318',
#      '145231',
#      '145671',
#      '146675',
#      '148676',
#      '148776',
#      '1487858',
#      '1562577',
#      '1569605',
#      '158194',
#      '1587943',
#      '1589731',
#      '1611',
#      '161619',
#      '165869',
#      '1671545',
#      '1679',
#      '1694420',
#      '171343',
#      '1720843',
#      '1736232',
#      '1744949',
#      '1746839',
#      '17497',
#      '1754774',
#      '1767719',
#      '178626',
#      '1789430',
#      '179403',
#      '1794878',
#      '179778',
#      '1800896',
#      '1802302',
#      '180306',
#      '1804651',
#      '18052',
#      '1813901',
#      '1817244',
#      '182631',
#      '1829683',
#      '1830192',
#      '1830852',
#      '1843632',
#      '1843650',
#      '1843684',
#      '1844712',
#      '1845258',
#      '1853249',
#      '1860675',
#      '1875451',
#      '188055',
#      '1882394',
#      '1884048',
#      '1891096',
#      '189339',
#      '1897391',
#      '1911765',
#      '1914055',
#      '1917415',
#      '192984',
#      '1941695',
#      '1960285',
#      '196617',
#      '1968004',
#      '1969149',
#      '1969150',
#      '1969158',
#      '1969159',
#      '1969162',
#      '1969165',
#      '1971166',
#      '1971168',
#      '1972585',
#      '1972632',
#      '1972641',
#      '1972652',
#      '1972673',
#      '1972700',
#      '1973842',
#      '1974024',
#      '1974135',
#      '1974327',
#      '1977561',
#      '1977636',
#      '1977647',
#      '1977648',
#      '1987359',
#      '1989621',
#      '2002034',
#      '20034',
#      '2011873',
#      '2015224',
#      '2024034',
#      '2024035',
#      '2024553',
#      '2037029',
#      '2039898',
#      '2048342',
#      '205207',
#      '2055936',
#      '2055941',
#      '2055943',
#      '2055944',
#      '2055964',
#      '2055969',
#      '2058368',
#      '2059565',
#      '2065793',
#      '2068292',
#      '211162',
#      '2115749',
#      '21694',
#      '2194133',
#      '2219338',
#      '2226430',
#      '2226712',
#      '223444',
#      '2268702',
#      '228211',
#      '2306749',
#      '230707',
#      '231358',
#      '231389',
#      '2344498',
#      '235098',
#      '2353646',
#      '2368423',
#      '2370902',
#      '2377377',
#      '2389407',
#      '239168',
#      '2419471',
#      '2447853',
#      '2448032',
#      '2448206',
#      '2465223',
#      '2475221',
#      '2480327',
#      '2489074',
#      '250196',
#      '2508151',
#      '250906',
#      '2511706',
#      '2512300',
#      '252828',
#      '2532822',
#      '2545951',
#      '25504',
#      '2554698',
#      '2569722',
#      '261012',
#      '2644101',
#      '26599',
#      '2662203',
#      '2721445',
#      '2721531',
#      '2721544',
#      '2721559',
#      '2721792',
#      '2721904',
#      '2724196',
#      '2728228',
#      '2731882',
#      '2735924',
#      '2738684',
#      '2741327',
#      '2744779',
#      '2745178',
#      '2747220',
#      '2748195',
#      '2750459',
#      '27577',
#      '275821',
#      '27585',
#      '2764775',
#      '2780311',
#      '2794145',
#      '2800142',
#      '2815653',
#      '2820218',
#      '2820500',
#      '2823295',
#      '282938',
#      '2835928',
#      '2844506',
#      '2847988',
#      '2850810',
#      '2869631',
#      '2872671',
#      '2873156',
#      '2891142',
#      '2891150',
#      '2891363',
#      '2897038',
#      '2897104',
#      '2897134',
#      '2897305',
#      '2897436',
#      '2897465',
#      '2900362',
#      '2900372',
#      '2900434',
#      '2900470',
#      '2900478',
#      '2900516',
#      '2900563',
#      '2900583',
#      '2900596',
#      '2900616',
#      '2900626',
#      '2901478',
#      '2901480',
#      '2901490',
#      '2901493',
#      '2901500',
#      '2901502',
#      '2901505',
#      '2901508',
#      '2901516',
#      '2901517',
#      '2901519',
#      '2901739',
#      '2901753',
#      '2901758',
#      '2901764',
#      '2901769',
#      '2901783',
#      '2901806',
#      '2901818',
#      '2901820',
#      '2901893',
#      '2902371',
#      '2905508',
#      '2905518',
#      '2905549',
#      '2905599',
#      '2905734',
#      '2905914',
#      '2906619',
#      '2906661',
#      '2907704',
#      '2907712',
#      '2907723',
#      '2907738',
#      '2907745',
#      '2907752',
#      '2907853',
#      '2913190',
#      '2913195',
#      '2915921',
#      '2915929',
#      '2922949',
#      '2923162',
#      '2926256',
#      '292665',
#      '2928996',
#      '2933679',
#      '2934115',
#      '293821',
#      '2938528',
#      '2944813',
#      '2944814',
#      '2949568',
#      '2949569',
#      '2949585',
#      '2949621',
#      '2950032',
#      '2958508',
#      '2968220',
#      '2995991',
#      '2996436',
#      '3008797',
#      '3018652',
#      '3026615',
#      '303436',
#      '3037',
#      '3039451',
#      '3041175',
#      '3089251',
#      '30967',
#      '3101111',
#      '3106420',
#      '3106807',
#      '3117271',
#      '3137875',
#      '313955',
#      '3163276',
#      '3164012',
#      '3173530',
#      '3179636',
#      '318164',
#      '3210764',
#      '3214079',
#      '321628',
#      '322785',
#      '323895',
#      '3253614',
#      '325957',
#      '3272286',
#      '328874',
#      '3291928',
#      '32952',
#      '331713',
#      '3347424',
#      '338611',
#      '339454',
#      '3395889',
#      '341127',
#      '3412598',
#      '3437658',
#      '3448582',
#      '3464632',
#      '3466783',
#      '3479270',
#      '3481081',
#      '351532',
#      '3526564',
#      '3539275',
#      '3540723',
#      '354623',
#      '3586050',
#      '358675',
#      '3605712',
#      '3611047',
#      '3613746',
#      '3691960',
#      '3710342',
#      '37248',
#      '376483',
#      '3771973',
#      '3779589',
#      '3784841',
#      '3793324',
#      '3795942',
#      '3811279',
#      '3813444',
#      '3829231',
#      '3836539',
#      '3851538',
#      '3854417',
#      '385855',
#      '3877019',
#      '387716',
#      '3893830',
#      '3899066',
#      '3926189',
#      '39463',
#      '398395',
#      '401116',
#      '401226',
#      '4014376',
#      '402624',
#      '404532',
#      '4050195',
#      '406299',
#      '406420',
#      '4066939',
#      '4072470',
#      '408776',
#      '408777',
#      '4111966',
#      '4160044',
#      '4160090',
#      '4170065',
#      '4174444',
#      '4177181',
#      '4181532',
#      '4210501',
#      '42123',
#      '4221183',
#      '4237576',
#      '4259691',
#      '4260390',
#      '426371',
#      '4267521',
#      '4295963',
#      '4297754',
#      '435674',
#      '439268',
#      '439726',
#      '4451902',
#      '4458000',
#      '4467894',
#      '4478348',
#      '4503261',
#      '4506833',
#      '4521379',
#      '4559315',
#      '456908',
#      '4601543',
#      '4604877',
#      '4607183',
#      '4611961',
#      '4615214',
#      '4616542',
#      '463037',
#      '4643790',
#      '4647004',
#      '4649875',
#      '4659336',
#      '4664358',
#      '4681580',
#      '468535',
#      '4703308',
#      '4708581',
#      '4731724',
#      '474183',
#      '4763179',
#      '477098',
#      '4785024',
#      '4790230',
#      '479310',
#      '4803265',
#      '4806270',
#      '4822623',
#      '4832183',
#      '4860719',
#      '4887826',
#      '492742',
#      '4959021',
#      '4994101',
#      '499500',
#      '4995557',
#      '5000520',
#      '5004555',
#      '5010430',
#      '5012876',
#      '5016479',
#      '5017009',
#      '5063824',
#      '5075980',
#      '5084340',
#      '5085154',
#      '5086120',
#      '510836',
#      '511727',
#      '5126366',
#      '513616',
#      '5137934',
#      '5182640',
#      '5183628',
#      '5195178',
#      '5200738',
#      '5203275',
#      '5203826',
#      '5204021',
#      '5204901',
#      '5205384',
#      '5206191',
#      '5209530',
#      '5213031',
#      '5217990',
#      '5233057',
#      '523412',
#      '5247606',
#      '5289461',
#      '531354',
#      '533465',
#      '5348827',
#      '5373038',
#      '5383320',
#      '5456',
#      '5459393',
#      '5463500',
#      '5479309',
#      '5494411',
#      '550300',
#      '5509234',
#      '5543718',
#      '5585414',
#      '559500',
#      '563682',
#      '5640381',
#      '5650193',
#      '56597',
#      '5659851',
#      '5662240',
#      '5677293',
#      '5694297',
#      '572158',
#      '5731581',
#      '5746827',
#      '574850',
#      '5778663',
#      '579990',
#      '58680',
#      '5876378',
#      '588621',
#      '589596',
#      '596323',
#      '5996341',
#      '600746',
#      '604920',
#      '6058023',
#      '6080498',
#      '6140658',
#      '6142329',
#      '6172399',
#      '6172454',
#      '6190345',
#      '61927',
#      '6210951',
#      '62133',
#      '6269369',
#      '6273975',
#      '630069',
#      '631153',
#      '6396128',
#      '640610',
#      '6441306',
#      '6444156',
#      '649465',
#      '651869',
#      '665748',
#      '680540',
#      '69043',
#      '69155',
#      '692602',
#      '706170',
#      '710590',
#      '712708',
#      '722137',
#      '74061',
#      '7412',
#      '753014',
#      '756525',
#      '78656',
#      '81656',
#      '81718',
#      '826532',
#      '827808',
#      '833323',
#      '85218',
#      '87918',
#      '88265',
#      '906179',
#      '914718',
#      '91490',
#      '9176',
#      '91790',
#      '91944',
#      '929779',
#      '934114',
#      '940674',
#      '94578',
#      '95446',
#      '97666',
#      '97732',
#      '97757',
#      '97772',
#      '99655'])

# %% [markdown]
# Now, Lets check the street names of the various areas in Hyderabad, India

# %% [markdown]
# After auditing the file initially, I see that most of the problematic areas have been resolved except for the first address where the place name starts with a comma.
# Using string.punctuation to remove any unnecessary punctuations marks from the addresses!
#
# Another address which i found to wrong was 'Sikh Road, Old Bowenpally;nr Market Yard, Sikh Road, Radha Swamy Colony, Bowenpally,' => here the semicolon shows that they have to separated but when i checked on wiki both the places pointed to the same location hence, I joined them together into one address!

# %%
# %load audit.py
import xml.etree.cElementTree as ET
from collections import defaultdict
import re
import string
import pprint
from optparse import OptionParser

regex = re.compile(r'\b\S+\.?', re.IGNORECASE)

expected = ["Hyderabad", "Road", "Gunj", "Nagar", "Junction", "Hills", "Society"] #expected names in the dataset

mapping = {"hyderabad": "Hyderabad",
            "Nr.": "NR",
           "nr": "NR",
           "Ave.": "Avenue",
           "sbk": "SBK",
           "gandhi": "Gandhi",
           "bridge": "Bridge",
           "road": "Road",
           "Ft.": "Feet",
           "ft": "Feet",
           "Rd": "Road",
           "Rd.": "Road",
           "Rd,": "Road,",
           "rd": "Road",
           "Roads": "Road",
           "society": "Society",
           "soc.": "Society",
           "jn" : "Junction",
           "Jn." : "Junction",
           "Jn" : "Junction"                     
            }

# Search string for the regex. If it is matched and not in the expected list then add this as a key to the set.
def audit_street(street_types, street_name): 
    m = regex.search(street_name)
    if m:
        street_type = m.group()
        if street_type not in expected:
            street_types[street_type].add(street_name)

def is_street_name(elem): # Check if it is a street name
    return (elem.attrib['k'] == "addr:street")

def audit(osmfile): # return the list that satify the above two functions
    osm_file = open(osmfile, "r")
    street_types = defaultdict(set)
    #tree = ET.parse(osm_file)
    for event, elem in ET.iterparse(osm_file, events=("start",)):

        if elem.tag == "node" or elem.tag == "way":
            for tag in elem.iter("tag"):
                if is_street_name(tag):
                    audit_street(street_types, tag.attrib['v'])
                    
  
    return street_types

def findWholeWord(w): #Some street names have double occurance 
    return re.compile(r'\b({0})\b'.format(w), flags=re.IGNORECASE).search

#pprint.pprint(dict(audit(OSM_FILE))) # print the existing names

def string_case(s): # change string into titleCase except for UpperCase
    if s.isupper():
        return s
    else:
        return s.title()

# return the updated names
def update_name(name, mapping):
    name = name.split(' ')
    for i in range(len(name)):
        if name[i] in mapping:
            name[i] = mapping[name[i]]
            name[i] = string_case(name[i])
        elif name[i] in string.punctuation:
            name[i] = name[i].replace(',','')
        elif re.match('[^;\s]+', name[i]): 
            name[i] = name[i].split(';',1)[-1]
        else:
            name[i] = string_case(name[i])
    name = ' '.join(name)
    
# Further cleaning the address strings 
    if ('Sikh Road,') in name:
            name = name.replace('Sikh Road,','').replace('  ','').rstrip(',')
    elif name.startswith(","):
        name = name.replace(',','',1)
    elif name.startswith(" "):
        name = name.replace(' ','')
    elif name.endswith(","): 
            name = name.replace(',','')
    else:
        name = string_case(name)
      
    return name



# print the updated names
update_street = audit(OSM_FILE) 
for street_type, ways in update_street.iteritems():
    for name in ways:
        better_name = update_name(name, mapping)
        print name, "=>", better_name
# Out:
# , Jubilee Enclave-Hitech City => JubileeEnclave-HitechCity
# Jubilee Hills => Jubilee Hills
# S.R.Nagar => S.R.Nagar
# Golnaka Road => Golnaka Road
# tellapur road => Tellapur Road
# Balanagar Cross Road => Balanagar Cross Road
# BN Reddy Nagar => Bn Reddy Nagar
# manage rd => Manage Road
# Saraswathi nagar colony => Saraswathi Nagar Colony
# Liberty Road => Liberty Road
# Dhoolpet Road => Dhoolpet Road
# Beside Pranam Hospital => Beside Pranam Hospital
# R.C.Puram => R.C.Puram
# EFLU => EFLU
# B-73 apie, IDA, Balanagar, Hyderabad, => B-73 apie IDA Balanagar Hyderabad
# Jai jawan colony => Jai Jawan Colony
# sathyanarayana Puram Road => Sathyanarayana Puram Road
# Gautham Nagar => Gautham Nagar
# Harinagar Main Road,  Marinatha Church => Harinagar Main Road,  Marinatha Church
# Miyapur => Miyapur
# Opp Parda Gate King Koti Road => Opp Parda Gate King Koti Road
# dammaiguda => Dammaiguda
# baddam balreddy nagar => Baddam Balreddy Nagar
# Cherlapalli Industrial Area => Cherlapalli Industrial Area
# Madhuranagar Main Road => Madhuranagar Main Road
# Ameerpet Road - Panjagutta Main Road => Ameerpet Road - Panjagutta Main Road
# Barkatpura => Barkatpura
# Yousufguda Main Road => Yousufguda Main Road
# People's Hospital Lane, Kukatpally => People'S Hospital Lane, Kukatpally
# kukatpally road => Kukatpally Road
# DD COLONY,AMBERPET => DD COLONY,AMBERPET
# raimathnagar,yusufguda,near  government high school => Raimathnagar,Yusufguda,Near  Government High School
# WaveRock SEZ, IT Number 2, Nanakramguda,, Gachibowli Rd, Financial District, Nanakram Guda, => WaveRock SEZ IT Number 2 Nanakramguda Gachibowli Road Financial District Nanakram Guda
# miyapur x-roads => Miyapur X-Roads
# CENTRAL EXCISE COLONY ,AMBERPET => CENTRAL EXCISE COLONY ,AMBERPET
# Malkajgiri => Malkajgiri
# HCU Main Road (University of Hyderabad) => Hcu Main Road (University Of Hyderabad)
# L. B. Nagar Junction => L. B. Nagar Junction
# RAJENDRA NAGAR => RAJENDRA NAGAR
# LB Nagar => Lb Nagar
# Santoshima Colony => Santoshima Colony
# bk guda rd => Bk Guda Road
# ushodaya colony phase 1 => Ushodaya Colony Phase 1
# Oppsite. Hotel Sitara Grand, L.B. 'X', Road, Sai Sadan Complex, Vivekananda Colony, LB Nagar, Hydera => Oppsite. Hotel Sitara Grand, L.B. 'X', Road, Sai Sadan Complex, Vivekananda Colony, Lb Nagar, Hydera
# Paramount Hills => Paramount Hills
# Arul Colony => Arul Colony
# kamala nagar => Kamala Nagar
# police lines => Police Lines
# substation => Substation
# Rd No 2, Banjara Hills => Road No 2, Banjara Hills
# Sai Baba Nagar => Sai Baba Nagar
# Sai Baba Temple, Gudimalkapur, Mehedipatnam => Sai Baba Temple, Gudimalkapur, Mehedipatnam
# Manikonda Village, Gatchibowli SEZ, Madhava Reddy Colony, Gachibowli => Manikonda Village, Gatchibowli Sez, Madhava Reddy Colony, Gachibowli
# Raj Bhavan Road => Raj Bhavan Road
# Indra Nagar, Gachibowli => Indra Nagar, Gachibowli
# Borabanda Mothinagar road => Borabanda Mothinagar Road
# Narsinha Colony,Mallapur Rd => Narsinha Colony,Mallapur Road
# Street number 9 => Street Number 9
# Nizampet Road => Nizampet Road
# gandhi nagar road => Gandhi Nagar Road
# Yousuf Baba Dargah Road => Yousuf Baba Dargah Road
# Shanthi Nagar Colony => Shanthi Nagar Colony
# Sikh Road, Old Bowenpally;nr Market Yard, Sikh Road, Radha Swamy Colony, Bowenpally, =>  Old nr Market Yard,Radha Swamy Colony, Bowenpally

# %%
# !pip install cerberus
# !pip install schema
# Out:
# Requirement already satisfied: cerberus in f:\anaconda\lib\site-packages
# Requirement already satisfied: schema in f:\anaconda\lib\site-packages

# %%
# %load schema.py

schema = {
    'node': {
        'type': 'dict',
        'schema': {
            'id': {'required': True, 'type': 'integer', 'coerce': int},
            'lat': {'required': True, 'type': 'float', 'coerce': float},
            'lon': {'required': True, 'type': 'float', 'coerce': float},
            'user': {'required': True, 'type': 'string'},
            'uid': {'required': True, 'type': 'integer', 'coerce': int},
            'version': {'required': True, 'type': 'string'},
            'changeset': {'required': True, 'type': 'integer', 'coerce': int},
            'timestamp': {'required': True, 'type': 'string'}
        }
    },
    'node_tags': {
        'type': 'list',
        'schema': {
            'type': 'dict',
            'schema': {
                'id': {'required': True, 'type': 'integer', 'coerce': int},
                'key': {'required': True, 'type': 'string'},
                'value': {'required': True, 'type': 'string'},
                'type': {'required': True, 'type': 'string'}
            }
        }
    },
    'way': {
        'type': 'dict',
        'schema': {
            'id': {'required': True, 'type': 'integer', 'coerce': int},
            'user': {'required': True, 'type': 'string'},
            'uid': {'required': True, 'type': 'integer', 'coerce': int},
            'version': {'required': True, 'type': 'string'},
            'changeset': {'required': True, 'type': 'integer', 'coerce': int},
            'timestamp': {'required': True, 'type': 'string'}
        }
    },
    'way_nodes': {
        'type': 'list',
        'schema': {
            'type': 'dict',
            'schema': {
                'id': {'required': True, 'type': 'integer', 'coerce': int},
                'node_id': {'required': True, 'type': 'integer', 'coerce': int},
                'position': {'required': True, 'type': 'integer', 'coerce': int}
            }
        }
    },
    'way_tags': {
        'type': 'list',
        'schema': {
            'type': 'dict',
            'schema': {
                'id': {'required': True, 'type': 'integer', 'coerce': int},
                'key': {'required': True, 'type': 'string'},
                'value': {'required': True, 'type': 'string'},
                'type': {'required': True, 'type': 'string'}
            }
        }
    }
}

# %%
# %load data.py
#!/usr/bin/env python
import csv
import codecs
import re
import xml.etree.cElementTree as ET
import pprint

import cerberus

#import schema

from audit import update_name, is_street_name

OSM_PATH = 'HYD_OSM.osm'

NODES_PATH = "nodes.csv"
NODE_TAGS_PATH = "nodes_tags.csv"
WAYS_PATH = "ways.csv"
WAY_NODES_PATH = "ways_nodes.csv"
WAY_TAGS_PATH = "ways_tags.csv"

LOWER_COLON = re.compile(r'^([a-z]|_)+:([a-z]|_)+')
PROBLEMCHARS = re.compile(r'[=\+/&<>;\'"\?%#$@\,\. \t\r\n]')

SCHEMA = schema

# Make sure the fields order in the csvs matches the column order in the sql table schema
NODE_FIELDS = ['id', 'lat', 'lon', 'user', 'uid', 'version', 'changeset', 'timestamp']
NODE_TAGS_FIELDS = ['id', 'key', 'value', 'type']
WAY_FIELDS = ['id', 'user', 'uid', 'version', 'changeset', 'timestamp']
WAY_TAGS_FIELDS = ['id', 'key', 'value', 'type']
WAY_NODES_FIELDS = ['id', 'node_id', 'position']


def shape_element(element, node_attr_fields=NODE_FIELDS, way_attr_fields=WAY_FIELDS,
                  problem_chars=PROBLEMCHARS, default_tag_type='regular'):
    """Clean and shape node or way XML element to Python dict"""

    node_attribs = {}
    way_attribs = {}
    way_nodes = []
    tags = []  # Handle secondary tags the same way for both node and way elements

    # YOUR CODE HERE
     # YOUR CODE HERE
    if element.tag == 'node':
        for attrib in element.attrib:
            if attrib in NODE_FIELDS:
                node_attribs[attrib] = element.attrib[attrib]
                
        for child in element:
            node_tag = {}
            if LOWER_COLON.match(child.attrib['k']):
                node_tag['id'] = element.attrib['id']
                node_tag['value'] = child.attrib['v']
                node_tag['type'] = child.attrib['k'].split(':',1)[0]
                node_tag['key'] = child.attrib['k'].split(':',1)[1]
                tags.append(node_tag)
            
            elif PROBLEMCHARS.match(child.attrib['k']):
                 continue
            else:
                node_tag['type'] = 'regular'
                node_tag['key']  = child.attrib['k']
                node_tag['value'] = child.attrib['v']
                node_tag['id'] = element.attrib['id']
                tags.append(node_tag)
        
        return {'node': node_attribs, 'node_tags': tags}
    
    elif element.tag == 'way':
        for attrib in element.attrib:
            if attrib in WAY_FIELDS:
                way_attribs[attrib] = element.attrib[attrib]
            
        pos = 0
        for child in element:
            way_tags = {}
            way_node = {}
            
            if child.tag == 'tag':
                if LOWER_COLON.match(child.attrib['k']):
                    way_tags['id'] = element.attrib['id']
                    way_tags['value'] = child.attrib['v']
                    way_tags['type'] = child.attrib['k'].split(':',1)[0]
                    way_tags['key'] = child.attrib['k'].split(':',1)[1]
                    tags.append(way_tags)
                elif PROBLEMCHARS.match(child.attrib['k']):
                    continue
                    
                else:
                    way_tags['type'] = 'regular'
                    way_tags['key']  =  child.attrib['k']
                    way_tags['value'] = child.attrib['v']
                    way_tags['id'] = element.attrib['id']
                    tags.append(way_tags)
                
            elif child.tag == 'nd':
                way_node['id'] = element.attrib['id']
                way_node['node_id'] = child.attrib['ref']
                way_node['position'] = pos
                pos +=1
                way_nodes.append(way_node)
                
        return {'way': way_attribs, 'way_nodes': way_nodes, 'way_tags': tags}


# ================================================== #
#               Helper Functions                     #
# ================================================== #
def get_element(osm_file, tags=('node', 'way', 'relation')):
    """Yield element if it is the right type of tag"""

    context = ET.iterparse(osm_file, events=('start', 'end'))
    _, root = next(context)
    for event, elem in context:
        if event == 'end' and elem.tag in tags:
            yield elem
            root.clear()


def validate_element(element, validator, schema=SCHEMA):
    """Raise ValidationError if element does not match schema"""
    if validator.validate(element, schema) is not True:
        field, errors = next(validator.errors.iteritems())
        message_string = "\nElement of type '{0}' has the following errors:\n{1}"
        error_string = pprint.pformat(errors)
        
        raise Exception(message_string.format(field, error_string))


class UnicodeDictWriter(csv.DictWriter, object):
    """Extend csv.DictWriter to handle Unicode input"""

    def writerow(self, row):
        super(UnicodeDictWriter, self).writerow({
            k: (v.encode('utf-8') if isinstance(v, unicode) else v) for k, v in row.iteritems()
        })

    def writerows(self, rows):
        for row in rows:
            self.writerow(row)


# ================================================== #
#               Main Function                        #
# ================================================== #
def process_map(file_in, validate):
    """Iteratively process each XML element and write to csv(s)"""

    with codecs.open(NODES_PATH, 'w') as nodes_file, \
         codecs.open(NODE_TAGS_PATH, 'w') as nodes_tags_file, \
         codecs.open(WAYS_PATH, 'w') as ways_file, \
         codecs.open(WAY_NODES_PATH, 'w') as way_nodes_file, \
         codecs.open(WAY_TAGS_PATH, 'w') as way_tags_file:

        nodes_writer = UnicodeDictWriter(nodes_file, NODE_FIELDS)
        node_tags_writer = UnicodeDictWriter(nodes_tags_file, NODE_TAGS_FIELDS)
        ways_writer = UnicodeDictWriter(ways_file, WAY_FIELDS)
        way_nodes_writer = UnicodeDictWriter(way_nodes_file, WAY_NODES_FIELDS)
        way_tags_writer = UnicodeDictWriter(way_tags_file, WAY_TAGS_FIELDS)

        nodes_writer.writeheader()
        node_tags_writer.writeheader()
        ways_writer.writeheader()
        way_nodes_writer.writeheader()
        way_tags_writer.writeheader()

        validator = cerberus.Validator()

        for element in get_element(file_in, tags=('node', 'way')):
            el = shape_element(element)
            if el:
                if validate is True:
                    validate_element(el, validator)

                if element.tag == 'node':
                    nodes_writer.writerow(el['node'])
                    node_tags_writer.writerows(el['node_tags'])
                elif element.tag == 'way':
                    ways_writer.writerow(el['way'])
                    way_nodes_writer.writerows(el['way_nodes'])
                    way_tags_writer.writerows(el['way_tags'])


if __name__ == '__main__':
    # Note: Validation is ~ 10X slower. For the project consider using a small
    # sample of the map when validating.
    data = process_map(OSM_PATH, validate=True)
# Out:
# , Jubilee Enclave-Hitech City => Jubilee Enclave-Hitech City
# Jubilee Hills => Jubilee Hills
# S.R.Nagar => S.R.Nagar
# Golnaka Road => Golnaka Road
# tellapur road => Tellapur Road
# Balanagar Cross Road => Balanagar Cross Road
# BN Reddy Nagar => Bn Reddy Nagar
# manage rd => Manage Road
# Saraswathi nagar colony => Saraswathi Nagar Colony
# Liberty Road => Liberty Road
# Dhoolpet Road => Dhoolpet Road
# Beside Pranam Hospital => Beside Pranam Hospital
# R.C.Puram => R.C.Puram
# EFLU => EFLU
# B-73 apie, IDA, Balanagar, Hyderabad, => B-73 Apie, Ida, Balanagar, Hyderabad,
# Jai jawan colony => Jai Jawan Colony
# sathyanarayana Puram Road => Sathyanarayana Puram Road
# Gautham Nagar => Gautham Nagar
# Harinagar Main Road,  Marinatha Church => Harinagar Main Road,  Marinatha Church
# Miyapur => Miyapur
# Opp Parda Gate King Koti Road => Opp Parda Gate King Koti Road
# dammaiguda => Dammaiguda
# baddam balreddy nagar => Baddam Balreddy Nagar
# Cherlapalli Industrial Area => Cherlapalli Industrial Area
# Madhuranagar Main Road => Madhuranagar Main Road
# Ameerpet Road - Panjagutta Main Road => Ameerpet Road - Panjagutta Main Road
# Barkatpura => Barkatpura
# Yousufguda Main Road => Yousufguda Main Road
# People's Hospital Lane, Kukatpally => People'S Hospital Lane, Kukatpally
# kukatpally road => Kukatpally Road
# DD COLONY,AMBERPET => DD COLONY,AMBERPET
# raimathnagar,yusufguda,near  government high school => Raimathnagar,Yusufguda,Near  Government High School
# WaveRock SEZ, IT Number 2, Nanakramguda,, Gachibowli Rd, Financial District, Nanakram Guda, => Waverock Sez, It Number 2, Nanakramguda,, Gachibowli Road, Financial District, Nanakram Guda,
# miyapur x-roads => Miyapur X-Roads
# CENTRAL EXCISE COLONY ,AMBERPET => CENTRAL EXCISE COLONY ,AMBERPET
# Malkajgiri => Malkajgiri
# HCU Main Road (University of Hyderabad) => Hcu Main Road (University Of Hyderabad)
# L. B. Nagar Junction => L. B. Nagar Junction
# RAJENDRA NAGAR => RAJENDRA NAGAR
# LB Nagar => Lb Nagar
# Santoshima Colony => Santoshima Colony
# bk guda rd => Bk Guda Road
# ushodaya colony phase 1 => Ushodaya Colony Phase 1
# Oppsite. Hotel Sitara Grand, L.B. 'X', Road, Sai Sadan Complex, Vivekananda Colony, LB Nagar, Hydera => Oppsite. Hotel Sitara Grand, L.B. 'X', Road, Sai Sadan Complex, Vivekananda Colony, Lb Nagar, Hydera
# Paramount Hills => Paramount Hills
# Arul Colony => Arul Colony
# kamala nagar => Kamala Nagar
# police lines => Police Lines
# substation => Substation
# Rd No 2, Banjara Hills => Road No 2, Banjara Hills
# Sai Baba Nagar => Sai Baba Nagar
# Sai Baba Temple, Gudimalkapur, Mehedipatnam => Sai Baba Temple, Gudimalkapur, Mehedipatnam
# Manikonda Village, Gatchibowli SEZ, Madhava Reddy Colony, Gachibowli => Manikonda Village, Gatchibowli Sez, Madhava Reddy Colony, Gachibowli
# Raj Bhavan Road => Raj Bhavan Road
# Indra Nagar, Gachibowli => Indra Nagar, Gachibowli
# Borabanda Mothinagar road => Borabanda Mothinagar Road
# Narsinha Colony,Mallapur Rd => Narsinha Colony,Mallapur Road
# Street number 9 => Street Number 9
# Nizampet Road => Nizampet Road
# gandhi nagar road => Gandhi Nagar Road
# Yousuf Baba Dargah Road => Yousuf Baba Dargah Road
# Shanthi Nagar Colony => Shanthi Nagar Colony
# Sikh Road, Old Bowenpally;nr Market Yard, Sikh Road, Radha Swamy Colony, Bowenpally, =>  Old nr Market Yard,Radha Swamy Colony, Bowenpally

# %%
import xml.etree.ElementTree as ET
import pprint
import re
import codecs
import json


lower = re.compile(r'^([a-z]|_)*$')
lower_colon = re.compile(r'^([a-z]|_)*:([a-z]|_)*$')
problemchars = re.compile(r'[=\+/&<>;\'"\?%#$@\,\. \t\r\n]')
addresschars = re.compile(r'addr:(\w+)')
CREATED = [ "version", "changeset", "timestamp", "user", "uid"]
OSM_FILE = 'HYD_OSM.osm'

def shape_element(element):
    #node = defaultdict(set)
    node = {}
    if element.tag == "node" or element.tag == "way" :
        #create the dictionary based on exaclty the value in element attribute.
        node = {'created':{}, 'type':element.tag}
        for k in element.attrib:
            try:
                v = element.attrib[k]
            except KeyError:
                continue
            if k == 'lat' or k == 'lon':
                continue
            if k in CREATED:
                node['created'][k] = v
            else:
                node[k] = v
        try:
            node['pos']=[float(element.attrib['lat']),float(element.attrib['lon'])]
        except KeyError:
            pass
        
        if 'address' not in node.keys():
            node['address'] = {}
        #Iterate the content of the tag
        for stag in element.iter('tag'):
            #Init the dictionry

            k = stag.attrib['k']
            v = stag.attrib['v']
            #Checking if indeed prefix with 'addr' and no ':' afterwards
            if k.startswith('addr:'):
                if len(k.split(':')) == 2:
                    content = addresschars.search(k)
                    if content:
                        node['address'][content.group(1)] = v
            else:
                node[k]=v
        if not node['address']:
            node.pop('address',None)
        #Special case when the tag == way,  scrap all the nd key
        if element.tag == "way":
            node['node_refs'] = []
            for nd in element.iter('nd'):
                node['node_refs'].append(nd.attrib['ref'])
#         if  'address' in node.keys():
#             pprint.pprint(node['address'])
        return node
    else:
        return None


def process_map(file_in, pretty = False):
    """
    Process the osm file to json file to be prepared for input file to monggo
    """
    file_out = "{0}.json".format(file_in)
    data = []
    with codecs.open(file_out, "w") as fo:
        for _, element in ET.iterparse(file_in):
            el = shape_element(element)
            if el:
                data.append(el)
                if pretty:
                    fo.write(json.dumps(el, indent=2)+"\n")
                else:
                    fo.write(json.dumps(el) + "\n")
    return data

def test():

    data = process_map(OSM_FILE)
    print("success")
    #pprint.pprint(data[500])
    #print(data[0:6])

if __name__ == "__main__":
    test()
# Out:
# success

# %% [markdown]
# The processed map has ben saved to hyd_sample_new.osm.json Now that we have process the audited map file into array of JSON, let's put it into mongodb instance. this will take the map that we have been audited. First we load the script to insert the map

# %% [markdown]
# Okay let's test if the data is something that we expect

# %%
#data = process_map('hyderabad_india.osm',True)
#print(data[0:6])

# %% [markdown]
# The data seems look good. Now, let's put it into MongoDB

# %%
def get_db():
    """
    Creates a connection to a MongoDB that contains the imported clean data

    Args: None

    Returns: The wdw collection from the openstreet database

    """
    from pymongo import MongoClient

    client = MongoClient('localhost:27017')

    db = client.hyd_osm.hyd

    return db

# The JSON file was imported into MongoDB via the command line.  This will store the db for use with Python.
db_hyd = get_db()

# %%
#number of documents inserted
db_hyd.find().count() #799628 initial error one!
# Out:
# 399814

# %% [markdown]
# <H2> DATA OVERVIEW

# %%
import os

os.path.getsize('HYD_OSM.osm')
# Out:
# 74004875L

# %%
os.path.getsize('HYD_OSM.osm.json')
# Out:
# 86337045L

# %% [markdown]
# The size of the json file is around 86.33MB

# %% [markdown]
# <h4> Number of Unique Users:

# %%
len(db_hyd.distinct('created.user'))
# Out:
# 579

# %% [markdown]
# <h4>Number of nodes and ways

# %%
list(db_hyd.find({"type": "node"}))
# Out:
# [{u'_id': ObjectId('59c4271144d7b6c01911bb3e'),
#   u'created': {u'changeset': u'39288507',
#    u'timestamp': u'2016-05-13T10:35:13Z',
#    u'uid': u'2901769',
#    u'user': u'anushap',
#    u'version': u'3'},
#   u'id': u'245639966',
#   u'pos': [17.2112688, 78.6170616],
#   u'source': u'AND',
#   u'type': u'node'},
#  {u'_id': ObjectId('59c4271144d7b6c01911bb3f'),
#   u'created': {u'changeset': u'26521403',
#    u'timestamp': u'2014-11-03T09:18:52Z',
#    u'uid': u'2419471',
#    u'user': u'Baluhyd',
#    u'version': u'6'},
#   u'id': u'245640916',
#   u'pos': [17.4955648, 78.356671],
#   u'source': u'AND',
#   u'type': u'node'},
#  {u'_id': ObjectId('59c4271144d7b6c01911bb40'),
#   u'created': {u'changeset': u'635779',
#    u'timestamp': u'2008-10-30T18:07:09Z',
#    u'uid': u'61927',
#    u'user': u'AlexPleiner',
#    u'version': u'3'},
#   u'id': u'277246024',
#   u'pos': [17.4499932, 78.4669651],
#   u'type': u'node'},
#  {u'_id': ObjectId('59c4271144d7b6c01911bb41'),
#   u'created': {u'changeset': u'7959378',
#    u'timestamp': u'2011-04-25T06:06:50Z',
#    u'uid': u'180306',
#    u'user': u'Chaitanya Kumar CH',
#    u'version': u'2'},
#   u'id': u'289414470',
#   u'pos': [17.4187018, 78.4652536],
#   u'type': u'node'},
#  {u'_id': ObjectId('59c4271144d7b6c01911bb42'),
#   u'created': {u'changeset': u'7959378',
#    u'timestamp': u'2011-04-25T06:06:53Z',
#    u'uid': u'180306',
#    u'user': u'Chaitanya Kumar CH',
#    u'version': u'2'},
#   u'id': u'289416677',
#   u'pos': [17.4175816, 78.4653676],
#   u'type': u'node'},
#  {u'_id': ObjectId('59c4271144d7b6c01911bb43'),
#   u'created': {u'changeset': u'26519851',
#    u'timestamp': u'2014-11-03T07:48:03Z',
#    u'uid': u'2419471',
#    u'user': u'Baluhyd',
#    u'version': u'8'},
#   u'id': u'289418723',
#   u'pos': [17.4793512, 78.4184509],
#   u'type': u'node'},
#  {u'_id': ObjectId('59c4271144d7b6c01911bb44'),
#   u'created': {u'changeset': u'41136378',
#    u'timestamp': u'2016-07-31T01:15:12Z',
#    u'uid': u'1016290',
#    u'user': u'Amaroussi',
#    u'version': u'9'},
#   u'id': u'289419498',
#   u'pos': [17.4958924, 78.3154781],
#   u'type': u'node'},
#  {u'_id': ObjectId('59c4271144d7b6c01911bb45'),
#   u'created': {u'changeset': u'26384827',
#    u'timestamp': u'2014-10-28T11:07:59Z',
#    u'uid': u'2419471',
#    u'user': u'Baluhyd',
#    u'version': u'6'},
#   u'id': u'289509865',
#   u'pos': [17.4258033, 78.4570923],
#   u'type': u'node'},
#  {u'_id': ObjectId('59c4271144d7b6c01911bb46'),
#   u'created': {u'changeset': u'11823536',
#    u'timestamp': u'2012-06-07T10:18:18Z',
#    u'uid': u'282938',
#    u'user': u'FlankerH',
#    u'version': u'7'},
#   u'id': u'289509879',
#   u'pos': [17.4221432, 78.4626724],
#   u'type': u'node'},
#  {u'_id': ObjectId('59c4271144d7b6c01911bb47'),
#   u'created': {u'changeset': u'27016607',
#    u'timestamp': u'2014-11-25T08:56:37Z',
#    u'uid': u'2419471',
#    u'user': u'Baluhyd',
#    u'version': u'20'},
#   u'id': u'289510340',
#   u'pos': [17.4281482, 78.4533031],
#   u'type': u'node'},
#  {u'_id': ObjectId('59c4271144d7b6c01911bb48'),
#   u'created': {u'changeset': u'15323798',
#    u'timestamp': u'2013-03-11T04:58:36Z',
#    u'uid': u'180306',
#    u'user': u'Chaitanya Kumar CH',
#    u'version': u'9'},
#   u'id': u'289511466',
#   u'pos': [17.4075271, 78.4604995],
#   u'type': u'node'},
#  {u'_id': ObjectId('59c4271144d7b6c01911bb49'),
#   u'created': {u'changeset': u'40860317',
#    u'timestamp': u'2016-07-19T14:44:10Z',
#    u'uid': u'1016290',
#    u'user': u'Amaroussi',
#    u'version': u'10'},
#   u'id': u'289513519',
#   u'pos': [17.420071, 78.4478689],
#   u'type': u'node'},
#  {u'_id': ObjectId('59c4271144d7b6c01911bb4a'),
#   u'created': {u'changeset': u'26518587',
#    u'timestamp': u'2014-11-03T05:27:38Z',
#    u'uid': u'2419471',
#    u'user': u'Baluhyd',
#    u'version': u'26'},
#   u'id': u'289517370',
#   u'pos': [17.442068, 78.3879888],
#   u'type': u'node'},
#  {u'_id': ObjectId('59c4271144d7b6c01911bb4b'),
#   u'created': {u'changeset': u'15323798',
#    u'timestamp': u'2013-03-11T04:58:37Z',
#    u'uid': u'180306',
#    u'user': u'Chaitanya Kumar CH',
#    u'version': u'5'},
#   u'id': u'289509620',
#   u'pos': [17.4156375, 78.4610979],
#   u'type': u'node'},
#  {u'_id': ObjectId('59c4271144d7b6c01911bb4c'),
#   u'created': {u'changeset': u'17409904',
#    u'timestamp': u'2013-08-19T11:51:26Z',
#    u'uid': u'579990',
#    u'user': u'vaandor',
#    u'version': u'8'},
#   u'id': u'245640730',
#   u'pos': [17.4510766, 78.4363796],
#   u'source': u'AND',
#   u'type': u'node'},
#  {u'_id': ObjectId('59c4271144d7b6c01911bb4d'),
#   u'admin_level': u'4',
#   u'capital': u'4',
#   u'created': {u'changeset': u'47074993',
#    u'timestamp': u'2017-03-22T18:07:02Z',
#    u'uid': u'2815653',
#    u'user': u'Srihari Thalla',
#    u'version': u'28'},
#   u'ele': u'505',
#   u'gns:dsg': u'ADM2',
#   u'gns:uni': u'-2912533',
#   u'id': u'245640543',
#   u'is_capital': u'state',
#   u'is_in:iso_3166_2': u'IN-TG',
#   u'name': u'Hyderabad',
#   u'name:hi': u'\u0939\u0948\u0926\u0930\u093e\u092c\u093e\u0926',
#   u'name:ja': u'\u30cf\u30a4\u30c7\u30e9\u30d0\u30fc\u30c9',
#   u'name:kn': u'\u0cb9\u0cc8\u0ca6\u0cb0\u0cbe\u0cac\u0cbe\u0ca6\u0ccd\u200c',
#   u'name:ru': u'\u0425\u0430\u0439\u0434\u0430\u0440\u0430\u0431\u0430\u0434',
#   u'name:ta': u'\u0bb9\u0bc8\u0ba4\u0bb0\u0bbe\u0baa\u0bbe\u0ba4\u0bcd',
#   u'name:te': u'\u0c39\u0c48\u0c26\u0c30\u0c3e\u0c2c\u0c3e\u0c26\u0c41',
#   u'name:zh': u'\u6d77\u5f97\u62c9\u5df4',
#   u'place': u'city',
#   u'place:cca': u'a1',
#   u'population': u'6809970',
#   u'population:date': u'2011',
#   u'pos': [17.3616227, 78.4747305],
#   u'source': u'GNS',
#   u'type': u'node',
#   u'wikidata': u'Q1361',
#   u'wikipedia': u'en:Hyderabad'},
#  {u'_id': ObjectId('59c4271144d7b6c01911bb4e'),
#   u'created': {u'changeset': u'17409904',
#    u'timestamp': u'2013-08-19T11:51:27Z',
#    u'uid': u'579990',
#    u'user': u'vaandor',
#    u'version': u'8'},
#   u'id': u'289521088',
#   u'pos': [17.4300906, 78.4500495],
#   u'type': u'node'},
#  {u'_id': ObjectId('59c4271144d7b6c01911bb4f'),
#   u'created': {u'changeset': u'13380400',
#    u'timestamp': u'2012-10-06T04:00:28Z',
#    u'uid': u'934114',
#    u'user': u'Kalyan_maverick',
#    u'version': u'8'},
#   u'id': u'289520298',
#   u'pos': [17.4357982, 78.4521257],
#   u'type': u'node'},
#  {u'_id': ObjectId('59c4271144d7b6c01911bb50'),
#   u'created': {u'changeset': u'26313988',
#    u'timestamp': u'2014-10-25T05:41:22Z',
#    u'uid': u'2419471',
#    u'user': u'Baluhyd',
#    u'version': u'5'},
#   u'id': u'289523853',
#   u'pos': [17.4731241, 78.4284797],
#   u'type': u'node'},
#  {u'_id': ObjectId('59c4271144d7b6c01911bb51'),
#   u'created': {u'changeset': u'46221671',
#    u'timestamp': u'2017-02-19T17:20:51Z',
#    u'uid': u'2815653',
#    u'user': u'Srihari Thalla',
#    u'version': u'4'},
#   u'id': u'289582419',
#   u'pos': [17.3911562, 78.4672948],
#   u'railway': u'buffer_stop',
#   u'type': u'node'},
#  {u'_id': ObjectId('59c4271144d7b6c01911bb52'),
#   u'created': {u'changeset': u'46594382',
#    u'timestamp': u'2017-03-05T12:07:51Z',
#    u'uid': u'2815653',
#    u'user': u'Srihari Thalla',
#    u'version': u'6'},
#   u'id': u'289582025',
#   u'name': u'Khairatabad',
#   u'platforms': u'2',
#   u'pos': [17.4129881, 78.4611879],
#   u'railway': u'station',
#   u'ref': u'KQD',
#   u'type': u'node',
#   u'wikidata': u'Q6399082',
#   u'wikipedia': u'en:Khairatabad railway station'},
#  {u'_id': ObjectId('59c4271144d7b6c01911bb53'),
#   u'created': {u'changeset': u'26385541',
#    u'timestamp': u'2014-10-28T11:43:20Z',
#    u'uid': u'2419471',
#    u'user': u'Baluhyd',
#    u'version': u'6'},
#   u'id': u'289658034',
#   u'pos': [17.4441641, 78.4610751],
#   u'type': u'node'},
#  {u'_id': ObjectId('59c4271144d7b6c01911bb54'),
#   u'created': {u'changeset': u'40950685',
#    u'timestamp': u'2016-07-22T13:44:35Z',
#    u'uid': u'1016290',
#    u'user': u'Amaroussi',
#    u'version': u'6'},
#   u'id': u'289658061',
#   u'pos': [17.4429082, 78.5005446],
#   u'type': u'node'},
#  {u'_id': ObjectId('59c4271144d7b6c01911bb55'),
#   u'created': {u'changeset': u'7993053',
#    u'timestamp': u'2011-04-28T10:00:25Z',
#    u'uid': u'180306',
#    u'user': u'Chaitanya Kumar CH',
#    u'version': u'2'},
#   u'id': u'289903729',
#   u'pos': [17.4062212, 78.4650644],
#   u'type': u'node'},
#  {u'_id': ObjectId('59c4271144d7b6c01911bb56'),
#   u'created': {u'changeset': u'39266170',
#    u'timestamp': u'2016-05-12T12:39:32Z',
#    u'uid': u'2900516',
#    u'user': u'jasvinderkaur',
#    u'version': u'5'},
#   u'id': u'289663551',
#   u'pos': [17.4172303, 78.4291234],
#   u'type': u'node'},
#  {u'_id': ObjectId('59c4271144d7b6c01911bb57'),
#   u'created': {u'changeset': u'15186640',
#    u'timestamp': u'2013-02-27T15:48:05Z',
#    u'uid': u'180306',
#    u'user': u'Chaitanya Kumar CH',
#    u'version': u'4'},
#   u'id': u'289904678',
#   u'pos': [17.4051376, 78.4638915],
#   u'type': u'node'},
#  {u'_id': ObjectId('59c4271144d7b6c01911bb58'),
#   u'created': {u'changeset': u'26588381',
#    u'timestamp': u'2014-11-06T09:06:23Z',
#    u'uid': u'2419471',
#    u'user': u'Baluhyd',
#    u'version': u'4'},
#   u'id': u'289904896',
#   u'pos': [17.4026813, 78.4672962],
#   u'type': u'node'},
#  {u'_id': ObjectId('59c4271144d7b6c01911bb59'),
#   u'created': {u'changeset': u'35095220',
#    u'timestamp': u'2015-11-05T06:42:03Z',
#    u'uid': u'1016290',
#    u'user': u'Amaroussi',
#    u'version': u'5'},
#   u'id': u'289909841',
#   u'pos': [17.4639437, 78.4726644],
#   u'type': u'node'},
#  {u'_id': ObjectId('59c4271144d7b6c01911bb5a'),
#   u'created': {u'changeset': u'26588304',
#    u'timestamp': u'2014-11-06T09:01:51Z',
#    u'uid': u'2419471',
#    u'user': u'Baluhyd',
#    u'version': u'3'},
#   u'id': u'289917121',
#   u'pos': [17.3994359, 78.4706995],
#   u'type': u'node'},
#  {u'_id': ObjectId('59c4271144d7b6c01911bb5b'),
#   u'created': {u'changeset': u'34220132',
#    u'timestamp': u'2015-09-24T07:52:25Z',
#    u'uid': u'1830852',
#    u'user': u'sourav1981',
#    u'version': u'6'},
#   u'id': u'289917156',
#   u'pos': [17.4026773, 78.4679094],
#   u'type': u'node'},
#  {u'_id': ObjectId('59c4271144d7b6c01911bb5c'),
#   u'created': {u'changeset': u'40089141',
#    u'timestamp': u'2016-06-17T10:27:39Z',
#    u'uid': u'2913195',
#    u'user': u'sathishshetty',
#    u'version': u'9'},
#   u'id': u'289928927',
#   u'pos': [17.3684739, 78.5315619],
#   u'type': u'node'},
#  {u'_id': ObjectId('59c4271144d7b6c01911bb5d'),
#   u'created': {u'changeset': u'10441120',
#    u'timestamp': u'2012-01-19T21:25:31Z',
#    u'uid': u'282938',
#    u'user': u'FlankerH',
#    u'version': u'3'},
#   u'id': u'289928942',
#   u'pos': [17.3610639, 78.5441676],
#   u'type': u'node'},
#  {u'_id': ObjectId('59c4271144d7b6c01911bb5e'),
#   u'created': {u'changeset': u'26405115',
#    u'timestamp': u'2014-10-29T05:42:46Z',
#    u'uid': u'2419471',
#    u'user': u'Baluhyd',
#    u'version': u'4'},
#   u'id': u'289928994',
#   u'pos': [17.3758911, 78.4965113],
#   u'type': u'node'},
#  {u'_id': ObjectId('59c4271144d7b6c01911bb5f'),
#   u'created': {u'changeset': u'8409505',
#    u'timestamp': u'2011-06-11T21:38:22Z',
#    u'uid': u'250196',
#    u'user': u'adivik2000',
#    u'version': u'2'},
#   u'id': u'289930528',
#   u'pos': [17.3696242, 78.4597773],
#   u'type': u'node'},
#  {u'_id': ObjectId('59c4271144d7b6c01911bb60'),
#   u'created': {u'changeset': u'15186640',
#    u'timestamp': u'2013-02-27T15:48:06Z',
#    u'uid': u'180306',
#    u'user': u'Chaitanya Kumar CH',
#    u'version': u'5'},
#   u'id': u'290891102',
#   u'pos': [17.4056565, 78.4609198],
#   u'type': u'node'},
#  {u'_id': ObjectId('59c4271144d7b6c01911bb61'),
#   u'created': {u'changeset': u'39555728',
#    u'timestamp': u'2016-05-25T12:54:57Z',
#    u'uid': u'2897134',
#    u'user': u'Naresh08',
#    u'version': u'7'},
#   u'id': u'291504334',
#   u'pos': [17.4803598, 78.3609896],
#   u'type': u'node'},
#  {u'_id': ObjectId('59c4271144d7b6c01911bb62'),
#   u'created': {u'changeset': u'26384827',
#    u'timestamp': u'2014-10-28T11:07:57Z',
#    u'uid': u'2419471',
#    u'user': u'Baluhyd',
#    u'version': u'6'},
#   u'id': u'289520169',
#   u'pos': [17.4296982, 78.4504632],
#   u'type': u'node'},
#  {u'_id': ObjectId('59c4271144d7b6c01911bb63'),
#   u'created': {u'changeset': u'26517395',
#    u'timestamp': u'2014-11-03T03:04:54Z',
#    u'uid': u'2419471',
#    u'user': u'Baluhyd',
#    u'version': u'27'},
#   u'id': u'289517395',
#   u'pos': [17.4497712, 78.3825826],
#   u'type': u'node'},
#  {u'_id': ObjectId('59c4271144d7b6c01911bb64'),
#   u'created': {u'changeset': u'33001343',
#    u'timestamp': u'2015-07-31T09:05:43Z',
#    u'uid': u'2869631',
#    u'user': u'Rajkumarmishra',
#    u'version': u'4'},
#   u'id': u'289928668',
#   u'pos': [17.3764795, 78.4960927],
#   u'type': u'node'},
#  {u'_id': ObjectId('59c4271144d7b6c01911bb65'),
#   u'created': {u'changeset': u'41182967',
#    u'timestamp': u'2016-08-02T04:59:04Z',
#    u'uid': u'1016290',
#    u'user': u'Amaroussi',
#    u'version': u'16'},
#   u'highway': u'crossing',
#   u'id': u'291504532',
#   u'pos': [17.4588717, 78.3660051],
#   u'type': u'node'},
#  {u'_id': ObjectId('59c4271144d7b6c01911bb66'),
#   u'created': {u'changeset': u'39595201',
#    u'timestamp': u'2016-05-27T05:09:52Z',
#    u'uid': u'2901769',
#    u'user': u'anushap',
#    u'version': u'2'},
#   u'id': u'298989636',
#   u'pos': [17.4588671, 78.5151531],
#   u'type': u'node'},
#  {u'_id': ObjectId('59c4271144d7b6c01911bb67'),
#   u'created': {u'changeset': u'39595201',
#    u'timestamp': u'2016-05-27T05:09:52Z',
#    u'uid': u'2901769',
#    u'user': u'anushap',
#    u'version': u'2'},
#   u'id': u'298990316',
#   u'pos': [17.4613866, 78.5163327],
#   u'type': u'node'},
#  {u'_id': ObjectId('59c4271144d7b6c01911bb68'),
#   u'created': {u'changeset': u'635779',
#    u'timestamp': u'2008-10-30T18:07:10Z',
#    u'uid': u'61927',
#    u'user': u'AlexPleiner',
#    u'version': u'2'},
#   u'id': u'298999320',
#   u'pos': [17.456257, 78.4589801],
#   u'type': u'node'},
#  {u'_id': ObjectId('59c4271144d7b6c01911bb69'),
#   u'created': {u'changeset': u'679155',
#    u'timestamp': u'2008-09-22T12:04:08Z',
#    u'uid': u'27585',
#    u'user': u'lawgoff',
#    u'version': u'1'},
#   u'id': u'298999358',
#   u'pos': [17.4548682, 78.4609987],
#   u'type': u'node'},
#  {u'_id': ObjectId('59c4271144d7b6c01911bb6a'),
#   u'created': {u'changeset': u'34710643',
#    u'timestamp': u'2015-10-18T13:03:01Z',
#    u'uid': u'1016290',
#    u'user': u'Amaroussi',
#    u'version': u'3'},
#   u'id': u'306593136',
#   u'pos': [17.3705695, 78.4769828],
#   u'type': u'node'},
#  {u'_id': ObjectId('59c4271144d7b6c01911bb6b'),
#   u'created': {u'changeset': u'8323566',
#    u'timestamp': u'2011-06-02T19:32:53Z',
#    u'uid': u'250196',
#    u'user': u'adivik2000',
#    u'version': u'2'},
#   u'id': u'306593146',
#   u'pos': [17.3613984, 78.4748362],
#   u'type': u'node'},
#  {u'_id': ObjectId('59c4271144d7b6c01911bb6c'),
#   u'created': {u'changeset': u'8332564',
#    u'timestamp': u'2011-06-03T19:35:11Z',
#    u'uid': u'250196',
#    u'user': u'adivik2000',
#    u'version': u'9'},
#   u'id': u'291505277',
#   u'pos': [17.4550404, 78.3780234],
#   u'type': u'node'},
#  {u'_id': ObjectId('59c4271144d7b6c01911bb6d'),
#   u'created': {u'changeset': u'39577167',
#    u'timestamp': u'2016-05-26T09:57:16Z',
#    u'uid': u'2897104',
#    u'user': u'Srikanth07',
#    u'version': u'2'},
#   u'id': u'306593192',
#   u'pos': [17.3295265, 78.4716054],
#   u'type': u'node'},
#  {u'_id': ObjectId('59c4271144d7b6c01911bb6e'),
#   u'created': {u'changeset': u'39577167',
#    u'timestamp': u'2016-05-26T09:57:16Z',
#    u'uid': u'2897104',
#    u'user': u'Srikanth07',
#    u'version': u'2'},
#   u'id': u'306593172',
#   u'pos': [17.3397507, 78.4682375],
#   u'type': u'node'},
#  {u'_id': ObjectId('59c4271144d7b6c01911bb6f'),
#   u'created': {u'changeset': u'34710643',
#    u'timestamp': u'2015-10-18T13:03:01Z',
#    u'uid': u'1016290',
#    u'user': u'Amaroussi',
#    u'version': u'3'},
#   u'id': u'306598185',
#   u'pos': [17.3688105, 78.4762826],
#   u'type': u'node'},
#  {u'_id': ObjectId('59c4271144d7b6c01911bb70'),
#   u'created': {u'changeset': u'37515227',
#    u'timestamp': u'2016-02-29T07:11:55Z',
#    u'uid': u'2662203',
#    u'user': u'Akash Kumar burman',
#    u'version': u'3'},
#   u'id': u'306598199',
#   u'pos': [17.3667566, 78.4680363],
#   u'type': u'node'},
#  {u'_id': ObjectId('59c4271144d7b6c01911bb71'),
#   u'created': {u'changeset': u'15217447',
#    u'timestamp': u'2013-03-02T04:54:30Z',
#    u'uid': u'180306',
#    u'user': u'Chaitanya Kumar CH',
#    u'version': u'3'},
#   u'id': u'306598211',
#   u'pos': [17.3666889, 78.4583469],
#   u'type': u'node'},
#  {u'_id': ObjectId('59c4271144d7b6c01911bb72'),
#   u'created': {u'changeset': u'527229',
#    u'timestamp': u'2008-10-23T15:39:56Z',
#    u'uid': u'61927',
#    u'user': u'AlexPleiner',
#    u'version': u'1'},
#   u'id': u'306598222',
#   u'pos': [17.3643469, 78.4640626],
#   u'type': u'node'},
#  {u'_id': ObjectId('59c4271144d7b6c01911bb73'),
#   u'created': {u'changeset': u'17869038',
#    u'timestamp': u'2013-09-16T14:19:42Z',
#    u'uid': u'1306',
#    u'user': u'PlaneMad',
#    u'version': u'2'},
#   u'id': u'306598233',
#   u'pos': [17.3621655, 78.4717589],
#   u'type': u'node'},
#  {u'_id': ObjectId('59c4271144d7b6c01911bb74'),
#   u'created': {u'changeset': u'39235901',
#    u'timestamp': u'2016-05-11T08:39:39Z',
#    u'uid': u'3779589',
#    u'user': u'Chenna2701',
#    u'version': u'3'},
#   u'id': u'306600840',
#   u'pos': [17.3683524, 78.4839269],
#   u'type': u'node'},
#  {u'_id': ObjectId('59c4271144d7b6c01911bb75'),
#   u'created': {u'changeset': u'41341452',
#    u'timestamp': u'2016-08-09T09:49:10Z',
#    u'uid': u'1016290',
#    u'user': u'Amaroussi',
#    u'version': u'5'},
#   u'id': u'306605180',
#   u'pos': [17.3730641, 78.4828373],
#   u'type': u'node'},
#  {u'_id': ObjectId('59c4271144d7b6c01911bb76'),
#   u'created': {u'changeset': u'41317900',
#    u'timestamp': u'2016-08-08T07:36:53Z',
#    u'uid': u'1016290',
#    u'user': u'Amaroussi',
#    u'version': u'3'},
#   u'id': u'306605201',
#   u'pos': [17.3744788, 78.484093],
#   u'type': u'node'},
#  {u'_id': ObjectId('59c4271144d7b6c01911bb77'),
#   u'created': {u'changeset': u'39504214',
#    u'timestamp': u'2016-05-23T09:08:02Z',
#    u'uid': u'2901516',
#    u'user': u'bindhu',
#    u'version': u'2'},
#   u'id': u'306605220',
#   u'pos': [17.3773992, 78.4893043],
#   u'type': u'node'},
#  {u'_id': ObjectId('59c4271144d7b6c01911bb78'),
#   u'created': {u'changeset': u'26564999',
#    u'timestamp': u'2014-11-05T07:26:53Z',
#    u'uid': u'2419471',
#    u'user': u'Baluhyd',
#    u'version': u'4'},
#   u'id': u'306605245',
#   u'pos': [17.3727781, 78.4993688],
#   u'type': u'node'},
#  {u'_id': ObjectId('59c4271144d7b6c01911bb79'),
#   u'created': {u'changeset': u'39396692',
#    u'timestamp': u'2016-05-18T10:06:00Z',
#    u'uid': u'2900372',
#    u'user': u'Apreethi',
#    u'version': u'3'},
#   u'id': u'306593158',
#   u'pos': [17.3526466, 78.4726779],
#   u'type': u'node'},
#  {u'_id': ObjectId('59c4271144d7b6c01911bb7a'),
#   u'created': {u'changeset': u'26427745',
#    u'timestamp': u'2014-10-30T03:07:45Z',
#    u'uid': u'2419471',
#    u'user': u'Baluhyd',
#    u'version': u'2'},
#   u'id': u'306605261',
#   u'pos': [17.3664298, 78.5016929],
#   u'type': u'node'},
#  {u'_id': ObjectId('59c4271144d7b6c01911bb7b'),
#   u'created': {u'changeset': u'41317900',
#    u'timestamp': u'2016-08-08T07:36:53Z',
#    u'uid': u'1016290',
#    u'user': u'Amaroussi',
#    u'version': u'4'},
#   u'id': u'306599560',
#   u'pos': [17.3725376, 78.4813426],
#   u'type': u'node'},
#  {u'_id': ObjectId('59c4271144d7b6c01911bb7c'),
#   u'created': {u'changeset': u'27649122',
#    u'timestamp': u'2014-12-23T11:56:09Z',
#    u'uid': u'1306',
#    u'user': u'PlaneMad',
#    u'version': u'3'},
#   u'id': u'291526167',
#   u'pos': [17.4136184, 78.4656068],
#   u'type': u'node'},
#  {u'_id': ObjectId('59c4271144d7b6c01911bb7d'),
#   u'created': {u'changeset': u'527229',
#    u'timestamp': u'2008-10-23T16:14:42Z',
#    u'uid': u'61927',
#    u'user': u'AlexPleiner',
#    u'version': u'1'},
#   u'id': u'306605279',
#   u'pos': [17.361779, 78.5069681],
#   u'type': u'node'},
#  {u'_id': ObjectId('59c4271244d7b6c01911bb7e'),
#   u'created': {u'changeset': u'32768300',
#    u'timestamp': u'2015-07-21T05:39:29Z',
#    u'uid': u'2995991',
#    u'user': u'sramesh',
#    u'version': u'2'},
#   u'id': u'306605354',
#   u'pos': [17.3674428, 78.4950766],
#   u'type': u'node'},
#  {u'_id': ObjectId('59c4271244d7b6c01911bb7f'),
#   u'created': {u'changeset': u'39396692',
#    u'timestamp': u'2016-05-18T10:06:00Z',
#    u'uid': u'2900372',
#    u'user': u'Apreethi',
#    u'version': u'3'},
#   u'id': u'306605377',
#   u'pos': [17.3648366, 78.4805802],
#   u'type': u'node'},
#  {u'_id': ObjectId('59c4271244d7b6c01911bb80'),
#   u'created': {u'changeset': u'27062874',
#    u'timestamp': u'2014-11-27T08:42:20Z',
#    u'uid': u'2419471',
#    u'user': u'Baluhyd',
#    u'version': u'2'},
#   u'id': u'306605393',
#   u'pos': [17.3540003, 78.4780029],
#   u'type': u'node'},
#  {u'_id': ObjectId('59c4271244d7b6c01911bb81'),
#   u'created': {u'changeset': u'527229',
#    u'timestamp': u'2008-10-23T16:14:49Z',
#    u'uid': u'61927',
#    u'user': u'AlexPleiner',
#    u'version': u'1'},
#   u'id': u'306605409',
#   u'pos': [17.3608094, 78.4792042],
#   u'type': u'node'},
#  {u'_id': ObjectId('59c4271244d7b6c01911bb82'),
#   u'created': {u'changeset': u'527229',
#    u'timestamp': u'2008-10-23T16:33:58Z',
#    u'uid': u'61927',
#    u'user': u'AlexPleiner',
#    u'version': u'1'},
#   u'id': u'306609409',
#   u'pos': [17.3611884, 78.4886551],
#   u'type': u'node'},
#  {u'_id': ObjectId('59c4271244d7b6c01911bb83'),
#   u'created': {u'changeset': u'527229',
#    u'timestamp': u'2008-10-23T16:33:59Z',
#    u'uid': u'61927',
#    u'user': u'AlexPleiner',
#    u'version': u'1'},
#   u'id': u'306609432',
#   u'pos': [17.3618773, 78.5008342],
#   u'type': u'node'},
#  {u'_id': ObjectId('59c4271244d7b6c01911bb84'),
#   u'created': {u'changeset': u'527229',
#    u'timestamp': u'2008-10-23T16:14:44Z',
#    u'uid': u'61927',
#    u'user': u'AlexPleiner',
#    u'version': u'1'},
#   u'id': u'306605305',
#   u'pos': [17.3602143, 78.5168578],
#   u'type': u'node'},
#  {u'_id': ObjectId('59c4271244d7b6c01911bb85'),
#   u'created': {u'changeset': u'26430392',
#    u'timestamp': u'2014-10-30T08:01:55Z',
#    u'uid': u'2419471',
#    u'user': u'Baluhyd',
#    u'version': u'2'},
#   u'id': u'306609503',
#   u'pos': [17.3291625, 78.4834946],
#   u'type': u'node'},
#  {u'_id': ObjectId('59c4271244d7b6c01911bb86'),
#   u'created': {u'changeset': u'26431867',
#    u'timestamp': u'2014-10-30T09:46:15Z',
#    u'uid': u'2419471',
#    u'user': u'Baluhyd',
#    u'version': u'2'},
#   u'id': u'306609519',
#   u'pos': [17.3160006, 78.4660137],
#   u'type': u'node'},
#  {u'_id': ObjectId('59c4271244d7b6c01911bb87'),
#   u'created': {u'changeset': u'26430392',
#    u'timestamp': u'2014-10-30T08:01:54Z',
#    u'uid': u'2419471',
#    u'user': u'Baluhyd',
#    u'version': u'3'},
#   u'id': u'306609488',
#   u'pos': [17.3404718, 78.5022847],
#   u'type': u'node'},
#  {u'_id': ObjectId('59c4271244d7b6c01911bb88'),
#   u'created': {u'changeset': u'39450349',
#    u'timestamp': u'2016-05-20T13:02:42Z',
#    u'uid': u'3813444',
#    u'user': u'kharsha93',
#    u'version': u'3'},
#   u'id': u'306609549',
#   u'pos': [17.3133884, 78.441334],
#   u'type': u'node'},
#  {u'_id': ObjectId('59c4271244d7b6c01911bb89'),
#   u'created': {u'changeset': u'39450349',
#    u'timestamp': u'2016-05-20T13:02:43Z',
#    u'uid': u'3813444',
#    u'user': u'kharsha93',
#    u'version': u'3'},
#   u'id': u'306609559',
#   u'pos': [17.3071409, 78.4305098],
#   u'type': u'node'},
#  {u'_id': ObjectId('59c4271244d7b6c01911bb8a'),
#   u'created': {u'changeset': u'527229',
#    u'timestamp': u'2008-10-23T16:34:08Z',
#    u'uid': u'61927',
#    u'user': u'AlexPleiner',
#    u'version': u'1'},
#   u'id': u'306609569',
#   u'pos': [17.3030983, 78.4230406],
#   u'type': u'node'},
#  {u'_id': ObjectId('59c4271244d7b6c01911bb8b'),
#   u'created': {u'changeset': u'527229',
#    u'timestamp': u'2008-10-23T16:34:09Z',
#    u'uid': u'61927',
#    u'user': u'AlexPleiner',
#    u'version': u'1'},
#   u'id': u'306609583',
#   u'pos': [17.3594918, 78.4757305],
#   u'type': u'node'},
#  {u'_id': ObjectId('59c4271244d7b6c01911bb8c'),
#   u'created': {u'changeset': u'527229',
#    u'timestamp': u'2008-10-23T16:34:10Z',
#    u'uid': u'61927',
#    u'user': u'AlexPleiner',
#    u'version': u'1'},
#   u'id': u'306609593',
#   u'pos': [17.3572412, 78.4813662],
#   u'type': u'node'},
#  {u'_id': ObjectId('59c4271244d7b6c01911bb8d'),
#   u'created': {u'changeset': u'39261741',
#    u'timestamp': u'2016-05-12T09:17:34Z',
#    u'uid': u'2901516',
#    u'user': u'bindhu',
#    u'version': u'4'},
#   u'id': u'306609628',
#   u'pos': [17.3497159, 78.4964072],
#   u'type': u'node'},
#  {u'_id': ObjectId('59c4271244d7b6c01911bb8e'),
#   u'created': {u'changeset': u'39580897',
#    u'timestamp': u'2016-05-26T12:58:26Z',
#    u'uid': u'2897104',
#    u'user': u'Srikanth07',
#    u'version': u'3'},
#   u'id': u'306609645',
#   u'pos': [17.3435933, 78.5001478],
#   u'type': u'node'},
#  {u'_id': ObjectId('59c4271244d7b6c01911bb8f'),
#   u'created': {u'changeset': u'527229',
#    u'timestamp': u'2008-10-23T16:34:16Z',
#    u'uid': u'61927',
#    u'user': u'AlexPleiner',
#    u'version': u'1'},
#   u'id': u'306609668',
#   u'pos': [17.3519604, 78.5053919],
#   u'type': u'node'},
#  {u'_id': ObjectId('59c4271244d7b6c01911bb90'),
#   u'created': {u'changeset': u'26428884',
#    u'timestamp': u'2014-10-30T05:37:07Z',
#    u'uid': u'2419471',
#    u'user': u'Baluhyd',
#    u'version': u'2'},
#   u'id': u'306609680',
#   u'pos': [17.345655, 78.5230087],
#   u'type': u'node'},
#  {u'_id': ObjectId('59c4271244d7b6c01911bb91'),
#   u'created': {u'changeset': u'26428884',
#    u'timestamp': u'2014-10-30T05:37:06Z',
#    u'uid': u'2419471',
#    u'user': u'Baluhyd',
#    u'version': u'2'},
#   u'id': u'306609699',
#   u'pos': [17.3430462, 78.5441364],
#   u'type': u'node'},
#  {u'_id': ObjectId('59c4271244d7b6c01911bb92'),
#   u'created': {u'changeset': u'26428344',
#    u'timestamp': u'2014-10-30T04:15:51Z',
#    u'uid': u'2419471',
#    u'user': u'Baluhyd',
#    u'version': u'2'},
#   u'id': u'306610965',
#   u'pos': [17.3455913, 78.5499584],
#   u'type': u'node'},
#  {u'_id': ObjectId('59c4271244d7b6c01911bb93'),
#   u'created': {u'changeset': u'527229',
#    u'timestamp': u'2008-10-23T16:34:01Z',
#    u'uid': u'61927',
#    u'user': u'AlexPleiner',
#    u'version': u'1'},
#   u'id': u'306609468',
#   u'pos': [17.349008, 78.5085129],
#   u'type': u'node'},
#  {u'_id': ObjectId('59c4271244d7b6c01911bb94'),
#   u'created': {u'changeset': u'26773188',
#    u'timestamp': u'2014-11-14T09:50:49Z',
#    u'uid': u'2419471',
#    u'user': u'Baluhyd',
#    u'version': u'2'},
#   u'id': u'306610988',
#   u'pos': [17.3379771, 78.5405173],
#   u'type': u'node'},
#  {u'_id': ObjectId('59c4271244d7b6c01911bb95'),
#   u'created': {u'changeset': u'26773188',
#    u'timestamp': u'2014-11-14T09:50:50Z',
#    u'uid': u'2419471',
#    u'user': u'Baluhyd',
#    u'version': u'2'},
#   u'id': u'306610999',
#   u'pos': [17.3384397, 78.5277423],
#   u'type': u'node'},
#  {u'_id': ObjectId('59c4271244d7b6c01911bb96'),
#   u'created': {u'changeset': u'26773188',
#    u'timestamp': u'2014-11-14T09:50:50Z',
#    u'uid': u'2419471',
#    u'user': u'Baluhyd',
#    u'version': u'2'},
#   u'id': u'306611009',
#   u'pos': [17.342832, 78.5121115],
#   u'type': u'node'},
#  {u'_id': ObjectId('59c4271244d7b6c01911bb97'),
#   u'created': {u'changeset': u'9940652',
#    u'timestamp': u'2011-11-25T05:32:19Z',
#    u'uid': u'511727',
#    u'user': u'sanganabongina',
#    u'version': u'3'},
#   u'id': u'306612076',
#   u'pos': [17.3564027, 78.530152],
#   u'type': u'node'},
#  {u'_id': ObjectId('59c4271244d7b6c01911bb98'),
#   u'created': {u'changeset': u'47872862',
#    u'timestamp': u'2017-04-17T14:12:58Z',
#    u'uid': u'5459393',
#    u'user': u'Satwik Aari',
#    u'version': u'4'},
#   u'id': u'306612092',
#   u'pos': [17.3541457, 78.5300975],
#   u'type': u'node'},
#  {u'_id': ObjectId('59c4271244d7b6c01911bb99'),
#   u'created': {u'changeset': u'33577024',
#    u'timestamp': u'2015-08-25T17:07:08Z',
#    u'uid': u'1240849',
#    u'user': u'ediyes',
#    u'version': u'4'},
#   u'id': u'306612104',
#   u'pos': [17.3518709, 78.5306382],
#   u'type': u'node'},
#  {u'_id': ObjectId('59c4271244d7b6c01911bb9a'),
#   u'created': {u'changeset': u'26428038',
#    u'timestamp': u'2014-10-30T03:42:22Z',
#    u'uid': u'2419471',
#    u'user': u'Baluhyd',
#    u'version': u'3'},
#   u'id': u'306605333',
#   u'pos': [17.3714787, 78.4999663],
#   u'type': u'node'},
#  {u'_id': ObjectId('59c4271244d7b6c01911bb9b'),
#   u'created': {u'changeset': u'527229',
#    u'timestamp': u'2008-10-23T16:34:12Z',
#    u'uid': u'61927',
#    u'user': u'AlexPleiner',
#    u'version': u'1'},
#   u'id': u'306609614',
#   u'pos': [17.3540725, 78.4911368],
#   u'type': u'node'},
#  {u'_id': ObjectId('59c4271244d7b6c01911bb9c'),
#   u'created': {u'changeset': u'9940652',
#    u'timestamp': u'2011-11-25T05:32:20Z',
#    u'uid': u'511727',
#    u'user': u'sanganabongina',
#    u'version': u'3'},
#   u'id': u'306612151',
#   u'pos': [17.3543458, 78.5255213],
#   u'type': u'node'},
#  {u'_id': ObjectId('59c4271244d7b6c01911bb9d'),
#   u'created': {u'changeset': u'9940652',
#    u'timestamp': u'2011-11-25T05:32:19Z',
#    u'uid': u'511727',
#    u'user': u'sanganabongina',
#    u'version': u'3'},
#   u'id': u'306612161',
#   u'pos': [17.354255, 78.5236716],
#   u'type': u'node'},
#  {u'_id': ObjectId('59c4271244d7b6c01911bb9e'),
#   u'created': {u'changeset': u'37515227',
#    u'timestamp': u'2016-02-29T07:11:57Z',
#    u'uid': u'2662203',
#    u'user': u'Akash Kumar burman',
#    u'version': u'4'},
#   u'id': u'306612141',
#   u'pos': [17.3514228, 78.5280816],
#   u'type': u'node'},
#  {u'_id': ObjectId('59c4271244d7b6c01911bb9f'),
#   u'created': {u'changeset': u'9940652',
#    u'timestamp': u'2011-11-25T05:32:18Z',
#    u'uid': u'511727',
#    u'user': u'sanganabongina',
#    u'version': u'3'},
#   u'id': u'306612184',
#   u'pos': [17.3589522, 78.5242133],
#   u'type': u'node'},
#  {u'_id': ObjectId('59c4271244d7b6c01911bba0'),
#   u'created': {u'changeset': u'9940652',
#    u'timestamp': u'2011-11-25T05:32:23Z',
#    u'uid': u'511727',
#    u'user': u'sanganabongina',
#    u'version': u'3'},
#   u'id': u'306612172',
#   u'pos': [17.357455, 78.5237472],
#   u'type': u'node'},
#  {u'_id': ObjectId('59c4271244d7b6c01911bba1'),
#   u'created': {u'changeset': u'527229',
#    u'timestamp': u'2008-10-23T16:49:58Z',
#    u'uid': u'61927',
#    u'user': u'AlexPleiner',
#    u'version': u'1'},
#   u'id': u'306612726',
#   u'pos': [17.3681854, 78.5194167],
#   u'type': u'node'},
#  {u'_id': ObjectId('59c4271244d7b6c01911bba2'),
#   u'created': {u'changeset': u'527229',
#    u'timestamp': u'2008-10-23T16:49:59Z',
#    u'uid': u'61927',
#    u'user': u'AlexPleiner',
#    u'version': u'1'},
#   u'id': u'306612739',
#   u'pos': [17.3616421, 78.5223034],
#   u'type': u'node'},
#  {u'_id': ObjectId('59c4271244d7b6c01911bba3'),
#   u'created': {u'changeset': u'32973589',
#    u'timestamp': u'2015-07-30T09:06:38Z',
#    u'uid': u'2869631',
#    u'user': u'Rajkumarmishra',
#    u'version': u'2'},
#   u'id': u'306612763',
#   u'pos': [17.3552452, 78.5313718],
#   u'type': u'node'},
#  {u'_id': ObjectId('59c4271244d7b6c01911bba4'),
#   u'created': {u'changeset': u'527229',
#    u'timestamp': u'2008-10-23T16:50:05Z',
#    u'uid': u'61927',
#    u'user': u'AlexPleiner',
#    u'version': u'1'},
#   u'id': u'306612779',
#   u'pos': [17.3513243, 78.5388315],
#   u'type': u'node'},
#  {u'_id': ObjectId('59c4271244d7b6c01911bba5'),
#   u'created': {u'changeset': u'41317900',
#    u'timestamp': u'2016-08-08T07:36:53Z',
#    u'uid': u'1016290',
#    u'user': u'Amaroussi',
#    u'version': u'3'},
#   u'id': u'306614603',
#   u'pos': [17.3702839, 78.4730182],
#   u'type': u'node'},
#  {u'_id': ObjectId('59c4271244d7b6c01911bba6'),
#   u'created': {u'changeset': u'41317900',
#    u'timestamp': u'2016-08-08T07:36:53Z',
#    u'uid': u'1016290',
#    u'user': u'Amaroussi',
#    u'version': u'3'},
#   u'id': u'306614619',
#   u'pos': [17.3721543, 78.4793197],
#   u'type': u'node'},
#  {u'_id': ObjectId('59c4271244d7b6c01911bba7'),
#   u'created': {u'changeset': u'41317900',
#    u'timestamp': u'2016-08-08T07:36:53Z',
#    u'uid': u'1016290',
#    u'user': u'Amaroussi',
#    u'version': u'3'},
#   u'id': u'306614644',
#   u'pos': [17.3771153, 78.48566],
#   u'type': u'node'},
#  {u'_id': ObjectId('59c4271244d7b6c01911bba8'),
#   u'created': {u'changeset': u'41317900',
#    u'timestamp': u'2016-08-08T07:36:54Z',
#    u'uid': u'1016290',
#    u'user': u'Amaroussi',
#    u'version': u'3'},
#   u'id': u'306614660',
#   u'pos': [17.3799928, 78.4914267],
#   u'type': u'node'},
#  {u'_id': ObjectId('59c4271244d7b6c01911bba9'),
#   u'created': {u'changeset': u'9940652',
#    u'timestamp': u'2011-11-25T05:32:20Z',
#    u'uid': u'511727',
#    u'user': u'sanganabongina',
#    u'version': u'3'},
#   u'id': u'306612114',
#   u'pos': [17.3502416, 78.5287889],
#   u'type': u'node'},
#  {u'_id': ObjectId('59c4271244d7b6c01911bbaa'),
#   u'created': {u'changeset': u'41317900',
#    u'timestamp': u'2016-08-08T07:36:54Z',
#    u'uid': u'1016290',
#    u'user': u'Amaroussi',
#    u'version': u'3'},
#   u'id': u'306614677',
#   u'pos': [17.3847967, 78.4992458],
#   u'type': u'node'},
#  {u'_id': ObjectId('59c4271244d7b6c01911bbab'),
#   u'created': {u'changeset': u'548209',
#    u'timestamp': u'2009-02-18T03:34:54Z',
#    u'uid': u'100487',
#    u'user': u'pavithrans',
#    u'version': u'2'},
#   u'id': u'306614688',
#   u'pos': [17.3856809, 78.5061716],
#   u'type': u'node'},
#  {u'_id': ObjectId('59c4271244d7b6c01911bbac'),
#   u'created': {u'changeset': u'527229',
#    u'timestamp': u'2008-10-23T16:58:38Z',
#    u'uid': u'61927',
#    u'user': u'AlexPleiner',
#    u'version': u'1'},
#   u'id': u'306614698',
#   u'pos': [17.3836568, 78.5135047],
#   u'type': u'node'},
#  {u'_id': ObjectId('59c4271244d7b6c01911bbad'),
#   u'created': {u'changeset': u'527229',
#    u'timestamp': u'2008-10-23T16:58:39Z',
#    u'uid': u'61927',
#    u'user': u'AlexPleiner',
#    u'version': u'1'},
#   u'id': u'306614708',
#   u'pos': [17.3771214, 78.5212126],
#   u'type': u'node'},
#  {u'_id': ObjectId('59c4271244d7b6c01911bbae'),
#   u'created': {u'changeset': u'527229',
#    u'timestamp': u'2008-10-23T16:58:40Z',
#    u'uid': u'61927',
#    u'user': u'AlexPleiner',
#    u'version': u'1'},
#   u'id': u'306614718',
#   u'pos': [17.3756485, 78.5293879],
#   u'type': u'node'},
#  {u'_id': ObjectId('59c4271244d7b6c01911bbaf'),
#   u'created': {u'changeset': u'527229',
#    u'timestamp': u'2008-10-23T16:58:41Z',
#    u'uid': u'61927',
#    u'user': u'AlexPleiner',
#    u'version': u'1'},
#   u'id': u'306614728',
#   u'pos': [17.378022, 78.5333565],
#   u'type': u'node'},
#  {u'_id': ObjectId('59c4271244d7b6c01911bbb0'),
#   u'created': {u'changeset': u'527229',
#    u'timestamp': u'2008-10-23T16:50:01Z',
#    u'uid': u'61927',
#    u'user': u'AlexPleiner',
#    u'version': u'1'},
#   u'id': u'306612750',
#   u'pos': [17.3577006, 78.527345],
#   u'type': u'node'},
#  {u'_id': ObjectId('59c4271244d7b6c01911bbb1'),
#   u'created': {u'changeset': u'9940652',
#    u'timestamp': u'2011-11-25T05:32:20Z',
#    u'uid': u'511727',
#    u'user': u'sanganabongina',
#    u'version': u'3'},
#   u'id': u'306612125',
#   u'pos': [17.3499115, 78.5281624],
#   u'type': u'node'},
#  {u'_id': ObjectId('59c4271244d7b6c01911bbb2'),
#   u'created': {u'changeset': u'527229',
#    u'timestamp': u'2008-10-23T17:01:39Z',
#    u'uid': u'61927',
#    u'user': u'AlexPleiner',
#    u'version': u'1'},
#   u'id': u'306615126',
#   u'pos': [17.3638101, 78.4556865],
#   u'type': u'node'},
#  {u'_id': ObjectId('59c4271244d7b6c01911bbb3'),
#   u'created': {u'changeset': u'527229',
#    u'timestamp': u'2008-10-23T17:01:40Z',
#    u'uid': u'61927',
#    u'user': u'AlexPleiner',
#    u'version': u'1'},
#   u'id': u'306615136',
#   u'pos': [17.3599072, 78.4497509],
#   u'type': u'node'},
#  {u'_id': ObjectId('59c4271244d7b6c01911bbb4'),
#   u'created': {u'changeset': u'41317900',
#    u'timestamp': u'2016-08-08T07:36:54Z',
#    u'uid': u'1016290',
#    u'user': u'Amaroussi',
#    u'version': u'3'},
#   u'id': u'306615116',
#   u'pos': [17.3679537, 78.4595548],
#   u'type': u'node'},
#  {u'_id': ObjectId('59c4271244d7b6c01911bbb5'),
#   u'created': {u'changeset': u'527229',
#    u'timestamp': u'2008-10-23T17:01:41Z',
#    u'uid': u'61927',
#    u'user': u'AlexPleiner',
#    u'version': u'1'},
#   u'id': u'306615146',
#   u'pos': [17.3665737, 78.4434395],
#   u'type': u'node'},
#  {u'_id': ObjectId('59c4271244d7b6c01911bbb6'),
#   u'created': {u'changeset': u'527229',
#    u'timestamp': u'2008-10-23T17:13:06Z',
#    u'uid': u'61927',
#    u'user': u'AlexPleiner',
#    u'version': u'1'},
#   u'id': u'306617495',
#   u'pos': [17.3791398, 78.4883643],
#   u'type': u'node'},
#  {u'_id': ObjectId('59c4271244d7b6c01911bbb7'),
#   u'created': {u'changeset': u'527229',
#    u'timestamp': u'2008-10-23T17:13:08Z',
#    u'uid': u'61927',
#    u'user': u'AlexPleiner',
#    u'version': u'1'},
#   u'id': u'306617515',
#   u'pos': [17.3801194, 78.4914232],
#   u'type': u'node'},
#  {u'_id': ObjectId('59c4271244d7b6c01911bbb8'),
#   u'created': {u'changeset': u'527229',
#    u'timestamp': u'2008-10-23T17:13:07Z',
#    u'uid': u'61927',
#    u'user': u'AlexPleiner',
#    u'version': u'1'},
#   u'id': u'306617505',
#   u'pos': [17.3799943, 78.4892561],
#   u'type': u'node'},
#  {u'_id': ObjectId('59c4271244d7b6c01911bbb9'),
#   u'created': {u'changeset': u'527229',
#    u'timestamp': u'2008-10-23T17:13:10Z',
#    u'uid': u'61927',
#    u'user': u'AlexPleiner',
#    u'version': u'1'},
#   u'id': u'306617535',
#   u'pos': [17.3809873, 78.4949953],
#   u'type': u'node'},
#  {u'_id': ObjectId('59c4271244d7b6c01911bbba'),
#   u'created': {u'changeset': u'527229',
#    u'timestamp': u'2008-10-23T17:13:12Z',
#    u'uid': u'61927',
#    u'user': u'AlexPleiner',
#    u'version': u'1'},
#   u'id': u'306617557',
#   u'pos': [17.3803383, 78.4950117],
#   u'type': u'node'},
#  {u'_id': ObjectId('59c4271244d7b6c01911bbbb'),
#   u'created': {u'changeset': u'527229',
#    u'timestamp': u'2008-10-23T17:13:12Z',
#    u'uid': u'61927',
#    u'user': u'AlexPleiner',
#    u'version': u'1'},
#   u'id': u'306617567',
#   u'pos': [17.3796346, 78.4928324],
#   u'type': u'node'},
#  {u'_id': ObjectId('59c4271244d7b6c01911bbbc'),
#   u'created': {u'changeset': u'527229',
#    u'timestamp': u'2008-10-23T17:13:13Z',
#    u'uid': u'61927',
#    u'user': u'AlexPleiner',
#    u'version': u'1'},
#   u'id': u'306617577',
#   u'pos': [17.3799278, 78.4931027],
#   u'type': u'node'},
#  {u'_id': ObjectId('59c4271244d7b6c01911bbbd'),
#   u'created': {u'changeset': u'527229',
#    u'timestamp': u'2008-10-23T17:13:14Z',
#    u'uid': u'61927',
#    u'user': u'AlexPleiner',
#    u'version': u'1'},
#   u'id': u'306617587',
#   u'pos': [17.3807801, 78.4952002],
#   u'type': u'node'},
#  {u'_id': ObjectId('59c4271244d7b6c01911bbbe'),
#   u'created': {u'changeset': u'527229',
#    u'timestamp': u'2008-10-23T17:13:15Z',
#    u'uid': u'61927',
#    u'user': u'AlexPleiner',
#    u'version': u'1'},
#   u'id': u'306617597',
#   u'pos': [17.379748, 78.4912716],
#   u'type': u'node'},
#  {u'_id': ObjectId('59c4271244d7b6c01911bbbf'),
#   u'created': {u'changeset': u'527229',
#    u'timestamp': u'2008-10-23T17:13:16Z',
#    u'uid': u'61927',
#    u'user': u'AlexPleiner',
#    u'version': u'1'},
#   u'id': u'306617607',
#   u'pos': [17.3788879, 78.4883999],
#   u'type': u'node'},
#  {u'_id': ObjectId('59c4271244d7b6c01911bbc0'),
#   u'created': {u'changeset': u'41317900',
#    u'timestamp': u'2016-08-08T07:36:54Z',
#    u'uid': u'1016290',
#    u'user': u'Amaroussi',
#    u'version': u'3'},
#   u'id': u'306615096',
#   u'pos': [17.369495, 78.4682719],
#   u'type': u'node'},
#  {u'_id': ObjectId('59c4271244d7b6c01911bbc1'),
#   u'created': {u'changeset': u'527229',
#    u'timestamp': u'2008-10-23T17:23:38Z',
#    u'uid': u'61927',
#    u'user': u'AlexPleiner',
#    u'version': u'1'},
#   u'id': u'306618771',
#   u'pos': [17.3744107, 78.4941818],
#   u'type': u'node'},
#  {u'_id': ObjectId('59c4271244d7b6c01911bbc2'),
#   u'created': {u'changeset': u'527229',
#    u'timestamp': u'2008-10-23T17:23:36Z',
#    u'uid': u'61927',
#    u'user': u'AlexPleiner',
#    u'version': u'1'},
#   u'id': u'306618760',
#   u'pos': [17.3791489, 78.4957421],
#   u'type': u'node'},
#  {u'_id': ObjectId('59c4271244d7b6c01911bbc3'),
#   u'created': {u'changeset': u'527229',
#    u'timestamp': u'2008-10-23T17:23:41Z',
#    u'uid': u'61927',
#    u'user': u'AlexPleiner',
#    u'version': u'1'},
#   u'id': u'306618789',
#   u'pos': [17.3708394, 78.4903915],
#   u'type': u'node'},
#  {u'_id': ObjectId('59c4271244d7b6c01911bbc4'),
#   u'created': {u'changeset': u'527229',
#    u'timestamp': u'2008-10-23T17:23:43Z',
#    u'uid': u'61927',
#    u'user': u'AlexPleiner',
#    u'version': u'1'},
#   u'id': u'306618800',
#   u'pos': [17.3658059, 78.4904029],
#   u'type': u'node'},
#  {u'_id': ObjectId('59c4271244d7b6c01911bbc5'),
#   u'created': {u'changeset': u'527229',
#    u'timestamp': u'2008-10-23T17:23:45Z',
#    u'uid': u'61927',
#    u'user': u'AlexPleiner',
#    u'version': u'1'},
#   u'id': u'306618813',
#   u'pos': [17.3610051, 78.4919689],
#   u'type': u'node'},
#  {u'_id': ObjectId('59c4271244d7b6c01911bbc6'),
#   u'created': {u'changeset': u'527229',
#    u'timestamp': u'2008-10-23T17:23:52Z',
#    u'uid': u'61927',
#    u'user': u'AlexPleiner',
#    u'version': u'1'},
#   u'id': u'306618838',
#   u'pos': [17.3579235, 78.4905971],
#   u'type': u'node'},
#  {u'_id': ObjectId('59c4271244d7b6c01911bbc7'),
#   u'created': {u'changeset': u'527229',
#    u'timestamp': u'2008-10-23T17:23:54Z',
#    u'uid': u'61927',
#    u'user': u'AlexPleiner',
#    u'version': u'1'},
#   u'id': u'306618851',
#   u'pos': [17.3562278, 78.4911911],
#   u'type': u'node'},
#  {u'_id': ObjectId('59c4271244d7b6c01911bbc8'),
#   u'created': {u'changeset': u'527229',
#    u'timestamp': u'2008-10-23T17:23:49Z',
#    u'uid': u'61927',
#    u'user': u'AlexPleiner',
#    u'version': u'1'},
#   u'id': u'306618826',
#   u'pos': [17.3581511, 78.4904596],
#   u'type': u'node'},
#  {u'_id': ObjectId('59c4271244d7b6c01911bbc9'),
#   u'created': {u'changeset': u'527229',
#    u'timestamp': u'2008-10-23T17:23:57Z',
#    u'uid': u'61927',
#    u'user': u'AlexPleiner',
#    u'version': u'1'},
#   u'id': u'306618862',
#   u'pos': [17.3536473, 78.4918379],
#   u'type': u'node'},
#  {u'_id': ObjectId('59c4271244d7b6c01911bbca'),
#   u'created': {u'changeset': u'527229',
#    u'timestamp': u'2008-10-23T17:24:00Z',
#    u'uid': u'61927',
#    u'user': u'AlexPleiner',
#    u'version': u'1'},
#   u'id': u'306618874',
#   u'pos': [17.3476381, 78.4899559],
#   u'type': u'node'},
#  {u'_id': ObjectId('59c4271244d7b6c01911bbcb'),
#   u'created': {u'changeset': u'527229',
#    u'timestamp': u'2008-10-23T17:24:04Z',
#    u'uid': u'61927',
#    u'user': u'AlexPleiner',
#    u'version': u'1'},
#   u'id': u'306618886',
#   u'pos': [17.3465094, 78.4922487],
#   u'type': u'node'},
#  {u'_id': ObjectId('59c4271244d7b6c01911bbcc'),
#   u'created': {u'changeset': u'527229',
#    u'timestamp': u'2008-10-23T17:24:06Z',
#    u'uid': u'61927',
#    u'user': u'AlexPleiner',
#    u'version': u'1'},
#   u'id': u'306618897',
#   u'pos': [17.3445195, 78.4921765],
#   u'type': u'node'},
#  {u'_id': ObjectId('59c4271244d7b6c01911bbcd'),
#   u'created': {u'changeset': u'527229',
#    u'timestamp': u'2008-10-23T17:13:09Z',
#    u'uid': u'61927',
#    u'user': u'AlexPleiner',
#    u'version': u'1'},
#   u'id': u'306617525',
#   u'pos': [17.3803344, 78.4930372],
#   u'type': u'node'},
#  {u'_id': ObjectId('59c4271244d7b6c01911bbce'),
#   u'created': {u'changeset': u'527229',
#    u'timestamp': u'2008-10-23T17:24:11Z',
#    u'uid': u'61927',
#    u'user': u'AlexPleiner',
#    u'version': u'1'},
#   u'id': u'306618919',
#   u'pos': [17.3402933, 78.4891203],
#   u'type': u'node'},
#  {u'_id': ObjectId('59c4271244d7b6c01911bbcf'),
#   u'created': {u'changeset': u'32947353',
#    u'timestamp': u'2015-07-29T06:17:46Z',
#    u'uid': u'2949569',
#    u'user': u'Rahuldhanraj',
#    u'version': u'2'},
#   u'id': u'306618930',
#   u'pos': [17.3382278, 78.4861517],
#   u'type': u'node'},
#  {u'_id': ObjectId('59c4271244d7b6c01911bbd0'),
#   u'created': {u'changeset': u'527229',
#    u'timestamp': u'2008-10-23T17:24:16Z',
#    u'uid': u'61927',
#    u'user': u'AlexPleiner',
#    u'version': u'1'},
#   u'id': u'306618940',
#   u'pos': [17.3365181, 78.4829437],
#   u'type': u'node'},
#  {u'_id': ObjectId('59c4271244d7b6c01911bbd1'),
#   u'created': {u'changeset': u'527229',
#    u'timestamp': u'2008-10-23T17:24:17Z',
#    u'uid': u'61927',
#    u'user': u'AlexPleiner',
#    u'version': u'1'},
#   u'id': u'306618952',
#   u'pos': [17.3343589, 78.4811228],
#   u'type': u'node'},
#  {u'_id': ObjectId('59c4271244d7b6c01911bbd2'),
#   u'created': {u'changeset': u'41317900',
#    u'timestamp': u'2016-08-08T07:36:54Z',
#    u'uid': u'1016290',
#    u'user': u'Amaroussi',
#    u'version': u'3'},
#   u'id': u'306615106',
#   u'pos': [17.3687859, 78.4626613],
#   u'type': u'node'},
#  {u'_id': ObjectId('59c4271244d7b6c01911bbd3'),
#   u'created': {u'changeset': u'527229',
#    u'timestamp': u'2008-10-23T17:24:09Z',
#    u'uid': u'61927',
#    u'user': u'AlexPleiner',
#    u'version': u'1'},
#   u'id': u'306618908',
#   u'pos': [17.3421057, 78.4908802],
#   u'type': u'node'},
#  {u'_id': ObjectId('59c4271244d7b6c01911bbd4'),
#   u'created': {u'changeset': u'527229',
#    u'timestamp': u'2008-10-23T17:24:18Z',
#    u'uid': u'61927',
#    u'user': u'AlexPleiner',
#    u'version': u'1'},
#   u'id': u'306618963',
#   u'pos': [17.3336575, 78.4793257],
#   u'type': u'node'},
#  {u'_id': ObjectId('59c4271244d7b6c01911bbd5'),
#   u'created': {u'changeset': u'527229',
#    u'timestamp': u'2008-10-23T17:40:15Z',
#    u'uid': u'61927',
#    u'user': u'AlexPleiner',
#    u'version': u'1'},
#   u'id': u'306621421',
#   u'pos': [17.3544143, 78.4695037],
#   u'type': u'node'},
#  {u'_id': ObjectId('59c4271244d7b6c01911bbd6'),
#   u'created': {u'changeset': u'33064720',
#    u'timestamp': u'2015-08-03T09:40:45Z',
#    u'uid': u'2644101',
#    u'user': u'Chetan_Gowda',
#    u'version': u'3'},
#   u'id': u'306621449',
#   u'pos': [17.354122, 78.4656211],
#   u'type': u'node'},
#  {u'_id': ObjectId('59c4271244d7b6c01911bbd7'),
#   u'created': {u'changeset': u'33024943',
#    u'timestamp': u'2015-08-01T07:06:17Z',
#    u'uid': u'2869631',
#    u'user': u'Rajkumarmishra',
#    u'version': u'3'},
#   u'id': u'306621503',
#   u'pos': [17.346239, 78.465905],
#   u'type': u'node'},
#  {u'_id': ObjectId('59c4271244d7b6c01911bbd8'),
#   u'created': {u'changeset': u'39579306',
#    u'timestamp': u'2016-05-26T11:49:27Z',
#    u'uid': u'2897104',
#    u'user': u'Srikanth07',
#    u'version': u'2'},
#   u'id': u'306621548',
#   u'pos': [17.3452801, 78.4563704],
#   u'type': u'node'},
#  {u'_id': ObjectId('59c4271244d7b6c01911bbd9'),
#   u'created': {u'changeset': u'527229',
#    u'timestamp': u'2008-10-23T17:46:23Z',
#    u'uid': u'61927',
#    u'user': u'AlexPleiner',
#    u'version': u'1'},
#   u'id': u'306622693',
#   u'pos': [17.3779436, 78.4825731],
#   u'type': u'node'},
#  {u'_id': ObjectId('59c4271244d7b6c01911bbda'),
#   u'created': {u'changeset': u'527229',
#    u'timestamp': u'2008-10-23T17:46:25Z',
#    u'uid': u'61927',
#    u'user': u'AlexPleiner',
#    u'version': u'1'},
#   u'id': u'306622703',
#   u'pos': [17.3803204, 78.4860734],
#   u'type': u'node'},
#  {u'_id': ObjectId('59c4271244d7b6c01911bbdb'),
#   u'created': {u'changeset': u'527229',
#    u'timestamp': u'2008-10-23T17:46:26Z',
#    u'uid': u'61927',
#    u'user': u'AlexPleiner',
#    u'version': u'1'},
#   u'id': u'306622714',
#   u'pos': [17.3791826, 78.487622],
#   u'type': u'node'},
#  {u'_id': ObjectId('59c4271244d7b6c01911bbdc'),
#   u'created': {u'changeset': u'8387906',
#    u'timestamp': u'2011-06-09T13:52:17Z',
#    u'uid': u'250196',
#    u'user': u'adivik2000',
#    u'version': u'2'},
#   u'id': u'306627944',
#   u'pos': [17.3822314, 78.5383513],
#   u'type': u'node'},
#  {u'_id': ObjectId('59c4271244d7b6c01911bbdd'),
#   u'created': {u'changeset': u'527229',
#    u'timestamp': u'2008-10-23T18:16:20Z',
#    u'uid': u'61927',
#    u'user': u'AlexPleiner',
#    u'version': u'1'},
#   u'id': u'306627963',
#   u'pos': [17.3828635, 78.542142],
#   u'type': u'node'},
#  {u'_id': ObjectId('59c4271244d7b6c01911bbde'),
#   u'created': {u'changeset': u'527229',
#    u'timestamp': u'2008-10-23T18:16:21Z',
#    u'uid': u'61927',
#    u'user': u'AlexPleiner',
#    u'version': u'1'},
#   u'id': u'306627990',
#   u'pos': [17.3828472, 78.546911],
#   u'type': u'node'},
#  {u'_id': ObjectId('59c4271244d7b6c01911bbdf'),
#   u'created': {u'changeset': u'527229',
#    u'timestamp': u'2008-10-23T17:40:39Z',
#    u'uid': u'61927',
#    u'user': u'AlexPleiner',
#    u'version': u'1'},
#   u'id': u'306621588',
#   u'pos': [17.3549498, 78.4583898],
#   u'type': u'node'},
#  {u'_id': ObjectId('59c4271244d7b6c01911bbe0'),
#   u'created': {u'changeset': u'13407523',
#    u'timestamp': u'2012-10-08T05:41:18Z',
#    u'uid': u'282938',
#    u'user': u'FlankerH',
#    u'version': u'2'},
#   u'id': u'306628012',
#   u'pos': [17.3801012, 78.5504404],
#   u'type': u'node'},
#  {u'_id': ObjectId('59c4271244d7b6c01911bbe1'),
#   u'created': {u'changeset': u'527229',
#    u'timestamp': u'2008-10-23T18:16:24Z',
#    u'uid': u'61927',
#    u'user': u'AlexPleiner',
#    u'version': u'1'},
#   u'id': u'306628030',
#   u'pos': [17.3818616, 78.5559961],
#   u'type': u'node'},
#  {u'_id': ObjectId('59c4271244d7b6c01911bbe2'),
#   u'created': {u'changeset': u'527229',
#    u'timestamp': u'2008-10-23T18:16:26Z',
#    u'uid': u'61927',
#    u'user': u'AlexPleiner',
#    u'version': u'1'},
#   u'id': u'306628049',
#   u'pos': [17.3861672, 78.5636231],
#   u'type': u'node'},
#  {u'_id': ObjectId('59c4271244d7b6c01911bbe3'),
#   u'created': {u'changeset': u'527229',
#    u'timestamp': u'2008-10-23T18:16:27Z',
#    u'uid': u'61927',
#    u'user': u'AlexPleiner',
#    u'version': u'1'},
#   u'id': u'306628067',
# ...
#   u'created': {u'changeset': u'802024',
#    u'timestamp': u'2008-11-27T14:11:50Z',
#    u'uid': u'61927',
#    u'user': u'AlexPleiner',
#    u'version': u'1'},
#   u'id': u'315057171',
#   u'pos': [17.4042955, 78.4847218],
#   u'type': u'node'},
#  {u'_id': ObjectId('59c4271244d7b6c01911beee'),
#   u'created': {u'changeset': u'40946612',
#    u'timestamp': u'2016-07-22T10:11:49Z',
#    u'uid': u'2662203',
#    u'user': u'Akash Kumar burman',
#    u'version': u'5'},
#   u'id': u'315057183',
#   u'pos': [17.409873, 78.4856014],
#   u'type': u'node'},
#  {u'_id': ObjectId('59c4271244d7b6c01911beef'),
#   u'created': {u'changeset': u'802024',
#    u'timestamp': u'2008-11-27T14:11:52Z',
#    u'uid': u'61927',
#    u'user': u'AlexPleiner',
#    u'version': u'1'},
#   u'id': u'315057194',
#   u'pos': [17.4099466, 78.4862689],
#   u'type': u'node'},
#  {u'_id': ObjectId('59c4271244d7b6c01911bef0'),
#   u'created': {u'changeset': u'38914031',
#    u'timestamp': u'2016-04-27T09:05:50Z',
#    u'uid': u'2901769',
#    u'user': u'anushap',
#    u'version': u'3'},
#   u'id': u'315057207',
#   u'pos': [17.40212, 78.4905245],
#   u'type': u'node'},
#  {u'_id': ObjectId('59c4271244d7b6c01911bef1'),
#   u'created': {u'changeset': u'26517395',
#    u'timestamp': u'2014-11-03T03:04:54Z',
#    u'uid': u'2419471',
#    u'user': u'Baluhyd',
#    u'version': u'30'},
#   u'id': u'314941035',
#   u'pos': [17.4480849, 78.3787432],
#   u'type': u'node'},
#  {u'_id': ObjectId('59c4271244d7b6c01911bef2'),
#   u'created': {u'changeset': u'802024',
#    u'timestamp': u'2008-11-27T14:34:45Z',
#    u'uid': u'61927',
#    u'user': u'AlexPleiner',
#    u'version': u'1'},
#   u'id': u'315058866',
#   u'pos': [17.4034754, 78.4922779],
#   u'type': u'node'},
#  {u'_id': ObjectId('59c4271244d7b6c01911bef3'),
#   u'created': {u'changeset': u'39291247',
#    u'timestamp': u'2016-05-13T12:58:11Z',
#    u'uid': u'2900372',
#    u'user': u'Apreethi',
#    u'version': u'4'},
#   u'id': u'315058850',
#   u'pos': [17.401666, 78.4987877],
#   u'type': u'node'},
#  {u'_id': ObjectId('59c4271244d7b6c01911bef4'),
#   u'created': {u'changeset': u'802024',
#    u'timestamp': u'2008-11-27T14:34:46Z',
#    u'uid': u'61927',
#    u'user': u'AlexPleiner',
#    u'version': u'1'},
#   u'id': u'315058884',
#   u'pos': [17.4065402, 78.4908205],
#   u'type': u'node'},
#  {u'_id': ObjectId('59c4271244d7b6c01911bef5'),
#   u'created': {u'changeset': u'32666643',
#    u'timestamp': u'2015-07-16T06:27:49Z',
#    u'uid': u'2996436',
#    u'user': u'ravikumar1',
#    u'version': u'2'},
#   u'id': u'315058896',
#   u'pos': [17.4082592, 78.4904144],
#   u'type': u'node'},
#  {u'_id': ObjectId('59c4271244d7b6c01911bef6'),
#   u'created': {u'changeset': u'39442282',
#    u'timestamp': u'2016-05-20T06:00:39Z',
#    u'uid': u'2901516',
#    u'user': u'bindhu',
#    u'version': u'3'},
#   u'id': u'315058908',
#   u'pos': [17.4079429, 78.4913587],
#   u'type': u'node'},
#  {u'_id': ObjectId('59c4271244d7b6c01911bef7'),
#   u'created': {u'changeset': u'32666643',
#    u'timestamp': u'2015-07-16T06:27:49Z',
#    u'uid': u'2996436',
#    u'user': u'ravikumar1',
#    u'version': u'2'},
#   u'id': u'315058923',
#   u'pos': [17.4088925, 78.4886692],
#   u'type': u'node'},
#  {u'_id': ObjectId('59c4271244d7b6c01911bef8'),
#   u'created': {u'changeset': u'26563024',
#    u'timestamp': u'2014-11-05T04:04:49Z',
#    u'uid': u'2419471',
#    u'user': u'Baluhyd',
#    u'version': u'4'},
#   u'id': u'314925348',
#   u'pos': [17.4275778, 78.405628],
#   u'type': u'node'},
#  {u'_id': ObjectId('59c4271244d7b6c01911bef9'),
#   u'created': {u'changeset': u'799115',
#    u'timestamp': u'2008-11-26T17:39:43Z',
#    u'uid': u'81718',
#    u'user': u'vvmanoj',
#    u'version': u'3'},
#   u'id': u'314945721',
#   u'pos': [17.4255799, 78.52914],
#   u'type': u'node'},
#  {u'_id': ObjectId('59c4271244d7b6c01911befa'),
#   u'created': {u'changeset': u'39442282',
#    u'timestamp': u'2016-05-20T06:00:39Z',
#    u'uid': u'2901516',
#    u'user': u'bindhu',
#    u'version': u'2'},
#   u'id': u'315060301',
#   u'pos': [17.4089916, 78.4901472],
#   u'type': u'node'},
#  {u'_id': ObjectId('59c4271244d7b6c01911befb'),
#   u'created': {u'changeset': u'38806715',
#    u'timestamp': u'2016-04-23T07:08:00Z',
#    u'uid': u'2900516',
#    u'user': u'jasvinderkaur',
#    u'version': u'2'},
#   u'id': u'315060317',
#   u'pos': [17.4097148, 78.4918379],
#   u'type': u'node'},
#  {u'_id': ObjectId('59c4271244d7b6c01911befc'),
#   u'created': {u'changeset': u'802024',
#    u'timestamp': u'2008-11-27T14:54:31Z',
#    u'uid': u'61927',
#    u'user': u'AlexPleiner',
#    u'version': u'1'},
#   u'id': u'315061308',
#   u'pos': [17.4095954, 78.4945546],
#   u'type': u'node'},
#  {u'_id': ObjectId('59c4271244d7b6c01911befd'),
#   u'created': {u'changeset': u'39442282',
#    u'timestamp': u'2016-05-20T06:00:39Z',
#    u'uid': u'2901516',
#    u'user': u'bindhu',
#    u'version': u'2'},
#   u'id': u'315061320',
#   u'pos': [17.409759, 78.4941029],
#   u'type': u'node'},
#  {u'_id': ObjectId('59c4271244d7b6c01911befe'),
#   u'created': {u'changeset': u'802024',
#    u'timestamp': u'2008-11-27T15:07:49Z',
#    u'uid': u'61927',
#    u'user': u'AlexPleiner',
#    u'version': u'1'},
#   u'id': u'315062441',
#   u'pos': [17.4000681, 78.4985714],
#   u'type': u'node'},
#  {u'_id': ObjectId('59c4271244d7b6c01911beff'),
#   u'created': {u'changeset': u'802024',
#    u'timestamp': u'2008-11-27T15:07:50Z',
#    u'uid': u'61927',
#    u'user': u'AlexPleiner',
#    u'version': u'1'},
#   u'id': u'315062456',
#   u'pos': [17.3990756, 78.4977828],
#   u'type': u'node'},
#  {u'_id': ObjectId('59c4271244d7b6c01911bf00'),
#   u'created': {u'changeset': u'802024',
#    u'timestamp': u'2008-11-27T15:07:52Z',
#    u'uid': u'61927',
#    u'user': u'AlexPleiner',
#    u'version': u'1'},
#   u'id': u'315062470',
#   u'pos': [17.4032571, 78.4963138],
#   u'type': u'node'},
#  {u'_id': ObjectId('59c4271244d7b6c01911bf01'),
#   u'created': {u'changeset': u'32689872',
#    u'timestamp': u'2015-07-17T07:15:23Z',
#    u'uid': u'2996436',
#    u'user': u'ravikumar1',
#    u'version': u'2'},
#   u'id': u'315062483',
#   u'pos': [17.4019543, 78.498966],
#   u'type': u'node'},
#  {u'_id': ObjectId('59c4271244d7b6c01911bf02'),
#   u'created': {u'changeset': u'39289118',
#    u'timestamp': u'2016-05-13T11:09:28Z',
#    u'uid': u'2900372',
#    u'user': u'Apreethi',
#    u'version': u'2'},
#   u'id': u'315062496',
#   u'pos': [17.4020193, 78.4990211],
#   u'type': u'node'},
#  {u'_id': ObjectId('59c4271244d7b6c01911bf03'),
#   u'created': {u'changeset': u'39290686',
#    u'timestamp': u'2016-05-13T12:31:04Z',
#    u'uid': u'2900372',
#    u'user': u'Apreethi',
#    u'version': u'3'},
#   u'id': u'315062705',
#   u'pos': [17.397601, 78.5018384],
#   u'type': u'node'},
#  {u'_id': ObjectId('59c4271244d7b6c01911bf04'),
#   u'created': {u'changeset': u'39289118',
#    u'timestamp': u'2016-05-13T11:09:28Z',
#    u'uid': u'2900372',
#    u'user': u'Apreethi',
#    u'version': u'3'},
#   u'id': u'315062692',
#   u'pos': [17.3997239, 78.502737],
#   u'type': u'node'},
#  {u'_id': ObjectId('59c4271244d7b6c01911bf05'),
#   u'created': {u'changeset': u'32689831',
#    u'timestamp': u'2015-07-17T07:11:53Z',
#    u'uid': u'2901490',
#    u'user': u'vikramsingh',
#    u'version': u'4'},
#   u'id': u'315066515',
#   u'pos': [17.4640137, 78.4557044],
#   u'type': u'node'},
#  {u'_id': ObjectId('59c4271244d7b6c01911bf06'),
#   u'created': {u'changeset': u'34574818',
#    u'timestamp': u'2015-10-11T17:58:51Z',
#    u'uid': u'404532',
#    u'user': u'jaimemd',
#    u'version': u'2'},
#   u'id': u'315066488',
#   u'pos': [17.4631017, 78.4506599],
#   u'type': u'node'},
#  {u'_id': ObjectId('59c4271244d7b6c01911bf07'),
#   u'created': {u'changeset': u'33088297',
#    u'timestamp': u'2015-08-04T06:19:39Z',
#    u'uid': u'3117271',
#    u'user': u'trushnam',
#    u'version': u'2'},
#   u'id': u'315066533',
#   u'pos': [17.463063, 78.4504179],
#   u'type': u'node'},
#  {u'_id': ObjectId('59c4271244d7b6c01911bf08'),
#   u'created': {u'changeset': u'33088297',
#    u'timestamp': u'2015-08-04T06:19:39Z',
#    u'uid': u'3117271',
#    u'user': u'trushnam',
#    u'version': u'2'},
#   u'id': u'315066543',
#   u'pos': [17.4625495, 78.4474075],
#   u'type': u'node'},
#  {u'_id': ObjectId('59c4271244d7b6c01911bf09'),
#   u'created': {u'changeset': u'33088297',
#    u'timestamp': u'2015-08-04T06:19:39Z',
#    u'uid': u'3117271',
#    u'user': u'trushnam',
#    u'version': u'2'},
#   u'id': u'315066553',
#   u'pos': [17.4623556, 78.4431885],
#   u'type': u'node'},
#  {u'_id': ObjectId('59c4271244d7b6c01911bf0a'),
#   u'created': {u'changeset': u'292867',
#    u'timestamp': u'2009-02-09T10:20:01Z',
#    u'uid': u'97772',
#    u'user': u'kmmohann',
#    u'version': u'2'},
#   u'id': u'315067251',
#   u'pos': [17.4594197, 78.4496552],
#   u'type': u'node'},
#  {u'_id': ObjectId('59c4271244d7b6c01911bf0b'),
#   u'created': {u'changeset': u'26380180',
#    u'timestamp': u'2014-10-28T05:29:20Z',
#    u'uid': u'2419471',
#    u'user': u'Baluhyd',
#    u'version': u'6'},
#   u'id': u'315067262',
#   u'pos': [17.453589, 78.4500729],
#   u'type': u'node'},
#  {u'_id': ObjectId('59c4271244d7b6c01911bf0c'),
#   u'created': {u'changeset': u'32672678',
#    u'timestamp': u'2015-07-16T12:23:10Z',
#    u'uid': u'2995991',
#    u'user': u'sramesh',
#    u'version': u'2'},
#   u'id': u'315063591',
#   u'pos': [17.4193038, 78.4874125],
#   u'type': u'node'},
#  {u'_id': ObjectId('59c4271244d7b6c01911bf0d'),
#   u'created': {u'changeset': u'802024',
#    u'timestamp': u'2008-11-27T15:50:44Z',
#    u'uid': u'61927',
#    u'user': u'AlexPleiner',
#    u'version': u'1'},
#   u'id': u'315066501',
#   u'pos': [17.4630443, 78.4588541],
#   u'type': u'node'},
#  {u'_id': ObjectId('59c4271244d7b6c01911bf0e'),
#   u'created': {u'changeset': u'15570563',
#    u'timestamp': u'2013-04-01T16:24:36Z',
#    u'uid': u'91490',
#    u'user': u'Heinz_V',
#    u'version': u'3'},
#   u'id': u'315068093',
#   u'pos': [17.4978056, 78.4760487],
#   u'type': u'node'},
#  {u'_id': ObjectId('59c4271244d7b6c01911bf0f'),
#   u'created': {u'changeset': u'34574818',
#    u'timestamp': u'2015-10-11T17:58:51Z',
#    u'uid': u'404532',
#    u'user': u'jaimemd',
#    u'version': u'2'},
#   u'id': u'315069319',
#   u'pos': [17.4615903, 78.4417971],
#   u'type': u'node'},
#  {u'_id': ObjectId('59c4271244d7b6c01911bf10'),
#   u'created': {u'changeset': u'802024',
#    u'timestamp': u'2008-11-27T16:02:20Z',
#    u'uid': u'61927',
#    u'user': u'AlexPleiner',
#    u'version': u'1'},
#   u'id': u'315068008',
#   u'pos': [17.4753883, 78.4705169],
#   u'type': u'node'},
#  {u'_id': ObjectId('59c4271244d7b6c01911bf11'),
#   u'created': {u'changeset': u'802024',
#    u'timestamp': u'2008-11-27T16:09:59Z',
#    u'uid': u'61927',
#    u'user': u'AlexPleiner',
#    u'version': u'1'},
#   u'id': u'315069342',
#   u'pos': [17.4625448, 78.4282695],
#   u'type': u'node'},
#  {u'_id': ObjectId('59c4271244d7b6c01911bf12'),
#   u'created': {u'changeset': u'34574818',
#    u'timestamp': u'2015-10-11T17:58:51Z',
#    u'uid': u'404532',
#    u'user': u'jaimemd',
#    u'version': u'2'},
#   u'id': u'315069359',
#   u'pos': [17.461444, 78.4346946],
#   u'type': u'node'},
#  {u'_id': ObjectId('59c4271244d7b6c01911bf13'),
#   u'created': {u'changeset': u'34574818',
#    u'timestamp': u'2015-10-11T17:58:51Z',
#    u'uid': u'404532',
#    u'user': u'jaimemd',
#    u'version': u'3'},
#   u'id': u'315069378',
#   u'pos': [17.4605041, 78.4219927],
#   u'type': u'node'},
#  {u'_id': ObjectId('59c4271244d7b6c01911bf14'),
#   u'created': {u'changeset': u'18839259',
#    u'timestamp': u'2013-11-11T16:50:23Z',
#    u'uid': u'91490',
#    u'user': u'Heinz_V',
#    u'version': u'3'},
#   u'id': u'315069875',
#   u'pos': [17.4637578, 78.3917416],
#   u'type': u'node'},
#  {u'_id': ObjectId('59c4271244d7b6c01911bf15'),
#   u'created': {u'changeset': u'18839259',
#    u'timestamp': u'2013-11-11T16:50:23Z',
#    u'uid': u'91490',
#    u'user': u'Heinz_V',
#    u'version': u'3'},
#   u'id': u'315069852',
#   u'pos': [17.4590013, 78.409355],
#   u'type': u'node'},
#  {u'_id': ObjectId('59c4271244d7b6c01911bf16'),
#   u'created': {u'changeset': u'141172',
#    u'timestamp': u'2008-12-05T08:57:48Z',
#    u'uid': u'81718',
#    u'user': u'vvmanoj',
#    u'version': u'2'},
#   u'id': u'315071218',
#   u'pos': [17.4822903, 78.3661339],
#   u'type': u'node'},
#  {u'_id': ObjectId('59c4271244d7b6c01911bf17'),
#   u'created': {u'changeset': u'27558210',
#    u'timestamp': u'2014-12-18T20:37:25Z',
#    u'uid': u'2226712',
#    u'user': u'dannykath',
#    u'version': u'2'},
#   u'id': u'315072763',
#   u'pos': [17.4657714, 78.4829179],
#   u'type': u'node'},
#  {u'_id': ObjectId('59c4271244d7b6c01911bf18'),
#   u'created': {u'changeset': u'802024',
#    u'timestamp': u'2008-11-27T16:32:30Z',
#    u'uid': u'61927',
#    u'user': u'AlexPleiner',
#    u'version': u'1'},
#   u'id': u'315072776',
#   u'pos': [17.4689566, 78.4803506],
#   u'type': u'node'},
#  {u'_id': ObjectId('59c4271244d7b6c01911bf19'),
#   u'created': {u'changeset': u'13368003',
#    u'timestamp': u'2012-10-05T01:49:36Z',
#    u'uid': u'934114',
#    u'user': u'Kalyan_maverick',
#    u'version': u'2'},
#   u'id': u'315072790',
#   u'pos': [17.4721904, 78.4739722],
#   u'type': u'node'},
#  {u'_id': ObjectId('59c4271244d7b6c01911bf1a'),
#   u'created': {u'changeset': u'802024',
#    u'timestamp': u'2008-11-27T16:32:33Z',
#    u'uid': u'61927',
#    u'user': u'AlexPleiner',
#    u'version': u'1'},
#   u'id': u'315072823',
#   u'pos': [17.4611641, 78.4856997],
#   u'type': u'node'},
#  {u'_id': ObjectId('59c4271244d7b6c01911bf1b'),
#   u'created': {u'changeset': u'8549517',
#    u'timestamp': u'2011-06-26T10:16:30Z',
#    u'uid': u'250196',
#    u'user': u'adivik2000',
#    u'version': u'2'},
#   u'id': u'315072858',
#   u'pos': [17.462124, 78.4940789],
#   u'type': u'node'},
#  {u'_id': ObjectId('59c4271244d7b6c01911bf1c'),
#   u'created': {u'changeset': u'26836481',
#    u'timestamp': u'2014-11-17T04:58:07Z',
#    u'uid': u'2419471',
#    u'user': u'Baluhyd',
#    u'version': u'4'},
#   u'id': u'315067278',
#   u'pos': [17.4520293, 78.43592],
#   u'type': u'node'},
#  {u'_id': ObjectId('59c4271244d7b6c01911bf1d'),
#   u'created': {u'changeset': u'33088297',
#    u'timestamp': u'2015-08-04T06:19:39Z',
#    u'uid': u'3117271',
#    u'user': u'trushnam',
#    u'version': u'2'},
#   u'id': u'315074115',
#   u'pos': [17.4612884, 78.4719845],
#   u'type': u'node'},
#  {u'_id': ObjectId('59c4271244d7b6c01911bf1e'),
#   u'created': {u'changeset': u'33088297',
#    u'timestamp': u'2015-08-04T06:19:40Z',
#    u'uid': u'3117271',
#    u'user': u'trushnam',
#    u'version': u'2'},
#   u'id': u'315074128',
#   u'pos': [17.4576435, 78.4603183],
#   u'type': u'node'},
#  {u'_id': ObjectId('59c4271244d7b6c01911bf1f'),
#   u'created': {u'changeset': u'26313685',
#    u'timestamp': u'2014-10-25T05:02:55Z',
#    u'uid': u'2419471',
#    u'user': u'Baluhyd',
#    u'version': u'2'},
#   u'id': u'315074144',
#   u'pos': [17.4629113, 78.4616692],
#   u'type': u'node'},
#  {u'_id': ObjectId('59c4271244d7b6c01911bf20'),
#   u'created': {u'changeset': u'11823536',
#    u'timestamp': u'2012-06-07T10:54:43Z',
#    u'uid': u'282938',
#    u'user': u'FlankerH',
#    u'version': u'2'},
#   u'id': u'315076213',
#   u'pos': [17.4443211, 78.4699052],
#   u'type': u'node'},
#  {u'_id': ObjectId('59c4271244d7b6c01911bf21'),
#   u'created': {u'changeset': u'11827107',
#    u'timestamp': u'2012-06-07T17:10:01Z',
#    u'uid': u'282938',
#    u'user': u'FlankerH',
#    u'version': u'2'},
#   u'id': u'315076228',
#   u'pos': [17.4454248, 78.4708556],
#   u'type': u'node'},
#  {u'_id': ObjectId('59c4271244d7b6c01911bf22'),
#   u'created': {u'changeset': u'802024',
#    u'timestamp': u'2008-11-27T16:49:57Z',
#    u'uid': u'61927',
#    u'user': u'AlexPleiner',
#    u'version': u'1'},
#   u'id': u'315076242',
#   u'pos': [17.4485095, 78.472504],
#   u'type': u'node'},
#  {u'_id': ObjectId('59c4271244d7b6c01911bf23'),
#   u'created': {u'changeset': u'18839259',
#    u'timestamp': u'2013-11-11T16:50:24Z',
#    u'uid': u'91490',
#    u'user': u'Heinz_V',
#    u'version': u'2'},
#   u'id': u'315069889',
#   u'pos': [17.4733457, 78.3830509],
#   u'type': u'node'},
#  {u'_id': ObjectId('59c4271244d7b6c01911bf24'),
#   u'created': {u'changeset': u'802024',
#    u'timestamp': u'2008-11-27T16:02:19Z',
#    u'uid': u'61927',
#    u'user': u'AlexPleiner',
#    u'version': u'1'},
#   u'id': u'315067995',
#   u'pos': [17.4686517, 78.4637146],
#   u'type': u'node'},
#  {u'_id': ObjectId('59c4271244d7b6c01911bf25'),
#   u'created': {u'changeset': u'40362250',
#    u'timestamp': u'2016-06-29T09:07:24Z',
#    u'uid': u'2900470',
#    u'user': u'saikumar',
#    u'version': u'3'},
#   u'id': u'315086172',
#   u'pos': [17.3369675, 78.496854],
#   u'type': u'node'},
#  ...]

# %% [markdown]
# <H2>EXPLORING HYDERABAD

# %% [markdown]
# <h3>Show 5 addresses that have street names

# %%
pipeline = [{'$match': {'address.street':{'$exists':1}}}, {'$limit' : 5}]
result  = db_hyd.aggregate(pipeline,useCursor=False)
pprint.pprint(list(result))
# Out:
# [{u'_id': ObjectId('59c4271244d7b6c01911cca1'),
#   u'address': {u'postcode': u'500047', u'street': u'Gautham Nagar'},
#   u'created': {u'changeset': u'9341311',
#                u'timestamp': u'2011-09-19T10:48:34Z',
#                u'uid': u'523412',
#                u'user': u'Yellajosyula Satish',
#                u'version': u'1'},
#   u'id': u'1437365133',
#   u'name': u'Satyam Saloom',
#   u'pos': [17.4531238, 78.5286273],
#   u'shop': u'hairdresser',
#   u'type': u'node'},
#  {u'_id': ObjectId('59c4271244d7b6c01911ccb9'),
#   u'address': {u'postcode': u'500047', u'street': u'Malkajgiri'},
#   u'amenity': u'pharmacy',
#   u'created': {u'changeset': u'9350587',
#                u'timestamp': u'2011-09-20T11:49:57Z',
#                u'uid': u'523412',
#                u'user': u'Yellajosyula Satish',
#                u'version': u'1'},
#   u'id': u'1438259298',
#   u'name': u'Gokul Medical Hall',
#   u'pos': [17.4499816, 78.5353596],
#   u'type': u'node'},
#  {u'_id': ObjectId('59c4271244d7b6c01911ce29'),
#   u'address': {u'street': u'Liberty Road'},
#   u'created': {u'changeset': u'10424504',
#                u'timestamp': u'2012-01-18T05:42:01Z',
#                u'uid': u'588621',
#                u'user': u'thednr83',
#                u'version': u'1'},
#   u'id': u'1595854207',
#   u'name': u"Dadu's Mithai Vatika",
#   u'pos': [17.4056818, 78.479066],
#   u'shop': u'confectionery',
#   u'type': u'node',
#   u'website': u'http://www.dadumithaivatika.com/'},
#  {u'_id': ObjectId('59c4271244d7b6c01911d2c7'),
#   u'address': {u'street': u'Rd No 2, Banjara Hills'},
#   u'created': {u'changeset': u'12862363',
#                u'timestamp': u'2012-08-26T06:08:41Z',
#                u'uid': u'826532',
#                u'user': u'NiteshSingh',
#                u'version': u'1'},
#   u'designation': u'Fiat Showroom',
#   u'id': u'1883402874',
#   u'name': u'Tejaswi Motors',
#   u'pos': [17.4264227, 78.4176008],
#   u'shop': u'car',
#   u'type': u'node'},
#  {u'_id': ObjectId('59c4271344d7b6c01911d5ce'),
#   u'address': {u'housenumber': u'3-4-526/29', u'street': u'Barkatpura'},
#   u'created': {u'changeset': u'26425210',
#                u'timestamp': u'2014-10-29T22:55:23Z',
#                u'uid': u'2226712',
#                u'user': u'dannykath',
#                u'version': u'3'},
#   u'highway': u'residential',
#   u'id': u'2193064456',
#   u'name': u'Vinuthna Villa Apartments',
#   u'pos': [17.3959871, 78.4947321],
#   u'type': u'node'}]

# %% [markdown]
# <h4>Top 5 contributing Users

# %%
pipeline = [
            {'$match': {'created.user':{'$exists':1}}},
            {'$group': {'_id':'$created.user',
                        'count':{'$sum':1}}},
            {'$sort': {'count':-1}},
            {'$limit' : 5}
]
result  = db_hyd.aggregate(pipeline,useCursor=False)
pprint.pprint(list(result))
# Out:
# [{u'_id': u'himabindhu', u'count': 14474},
#  {u'_id': u'saikumar', u'count': 13185},
#  {u'_id': u'bindhu', u'count': 12935},
#  {u'_id': u'anushapyata', u'count': 12185},
#  {u'_id': u'venkatkotha', u'count': 12147}]

# %% [markdown]
# <h3> What type of address do we have?

# %%
list(db_hyd.distinct("shop"))
# Out:
# [u'supermarket',
#  u'mall',
#  u'convenience',
#  u'car',
#  u'department_store',
#  u'electronics',
#  u'bakery',
#  u'alcohol',
#  u'music',
#  u'clothes',
#  u'hairdresser',
#  u'books',
#  u'confectionery',
#  u'motorcycle',
#  u'yes',
#  u'travel_agency',
#  u'variety_store',
#  u'cosmetics',
#  u'mobile_phone',
#  u'medical_supply',
#  u'stationery',
#  u'gift',
#  u'butcher',
#  u'copyshop',
#  u'optician',
#  u'sports',
#  u'car_repair']

# %% [markdown]
# <h3> List all the confectionery shops in Hyderabad

# %%
pipeline = [
            {'$match': {'shop':'confectionery',
                        'name':{'$exists':1}}},
            {'$project':{'_id':'$name',
                          'contact':'$phone'}}
]
result  = db_hyd.aggregate(pipeline,useCursor=False)
pprint.pprint(list(result))
# Out:
# [{u'_id': u"Dadu's Mithai Vatika"},
#  {u'_id': u'Mathwalle Doodh Falloda and Lassi'},
#  {u'_id': u'Agarwala sweets'}]
